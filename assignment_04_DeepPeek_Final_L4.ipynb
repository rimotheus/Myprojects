# %% [markdown]
# # Group Project / Assignment 4: Instruction finetuning a Llama-3.2 model
# **Assignment due 21 April 11:59pm**
#
# Welcome to the fourth and final assignment for 50.055 Machine Learning Operations. The third and fourth assignment together form the course group project. You will continue the work on a chatbot which can answer questions about SUTD to prospective students.
#
#
# **This assignment is a group assignment.**
#
# - Read the instructions in this notebook carefully
# - Add your solution code and answers in the appropriate places. The questions are marked as **QUESTION:**, the places where you need to add your code and text answers are marked as **ADD YOUR SOLUTION HERE**. The assignment is more open-ended than previous assignments, i.e. you have more freedom how to solve the problem and how to structure your code.
# - The completed notebook, including your added code and generated output will be your submission for the assignment.
# - The notebook should execute without errors from start to finish when you select "Restart Kernel and Run All Cells..". Please test this before submission.
# - Use the SUTD Education Cluster to solve and test the assignment. If you work on another environment, minimally test your work on the SUTD Education Cluster.
#
# **Rubric for assessment**
#
# Your submission will be graded using the following criteria.
# 1. Code executes: your code should execute without errors. The SUTD Education cluster should be used to ensure the same execution environment.
# 2. Correctness: the code should produce the correct result or the text answer should state the factual correct answer.
# 3. Style: your code should be written in a way that is clean and efficient. Your text answers should be relevant, concise and easy to understand.
# 4. Partial marks will be awarded for partially correct solutions.
# 5. Creativity and innovation: in this assignment you have more freedom to design your solution, compared to the first assignments. You can show of your creativity and innovative mindset.
# 6. There is a maximum of 310 points for this assignment.
#
# **ChatGPT policy**
#
# If you use AI tools, such as ChatGPT, to solve the assignment questions, you need to be transparent about its use and mark AI-generated content as such. In particular, you should include the following in addition to your final answer:
# - A copy or screenshot of the prompt you used
# - The name of the AI model
# - The AI generated output
# - An explanation why the answer is correct or what you had to change to arrive at the correct answer
#
# **Assignment Notes:** Please make sure to save the notebook as you go along. Submission Instructions are located at the bottom of the notebook.

# %% [markdown]
# ### Finetuning LLMs
#
# The goal of the assignment is to build a more advanced chatbot that can talk to prospective students and answer questions about SUTD.
#
# We will finetune a smaller 1B LLM on question-answer pairs which we synthetically generate. Then we will compare the finetuned and non-finetuned LLMs with and without RAG to see if we were able to improve the SUTD chatbot answer quality.
#
# We'll be leveraging `langchain`, `llama 3.2` and `Google AI STudio with Gemini 2.0`.
#
# Check out the docs:
# - [LangChain](https://docs.langchain.com/docs/)
# - [Llama 3.2](https://www.llama.com/docs/model-cards-and-prompt-formats/llama3_2/)
# - [Google AI Studio](https://aistudio.google.com/)
#
# Note: Google AI Studio provides a lot of free tokens but has certain rate limits. Write your code in a way that it can handle these limits.

# %% [markdown]
# # Install dependencies
# Use pip to install all required dependencies of this assignment in the cell below. Make sure to test this on the SUTD cluster as different environments have different software pre-installed.

# %%
# QUESTION: Install and import all required packages
# The rest of your code should execute without any import or dependency errors.

# **--- ADD YOUR SOLUTION HERE (10 points) ---**
# !pip install -U langchain langchain-community openai
# !pip install langchain-google-genai
# !pip install openai datasets huggingface_hub pandas scikit-learn
# !pip install --upgrade gradio

from langchain_google_genai import ChatGoogleGenerativeAI
from langchain.prompts import PromptTemplate
from langchain.chains import LLMChain

from openai import OpenAI
import pandas as pd
from datasets import Dataset, DatasetDict
from huggingface_hub import login
from sklearn.model_selection import train_test_split

from transformers import (
    AutoModelForCausalLM,
    AutoTokenizer,
    TrainingArguments,
    Trainer,
    DataCollatorForLanguageModeling,
)
from peft import LoraConfig, get_peft_model, PeftModel, PeftConfig
from datasets import load_dataset

import os
import time
import json
import torch
# Out:
# Requirement already satisfied: langchain in /usr/local/lib/python3.11/dist-packages (0.3.24)
# Requirement already satisfied: langchain-community in /usr/local/lib/python3.11/dist-packages (0.3.22)
# Requirement already satisfied: openai in /usr/local/lib/python3.11/dist-packages (1.75.0)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.55 in /usr/local/lib/python3.11/dist-packages (from langchain) (0.3.55)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.8 in /usr/local/lib/python3.11/dist-packages (from langchain) (0.3.8)
# Requirement already satisfied: langsmith<0.4,>=0.1.17 in /usr/local/lib/python3.11/dist-packages (from langchain) (0.3.31)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.11/dist-packages (from langchain) (2.11.3)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.11/dist-packages (from langchain) (2.0.40)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.11/dist-packages (from langchain) (2.32.3)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.11/dist-packages (from langchain) (6.0.2)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (3.11.15)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (9.1.2)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (2.9.1)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (0.4.0)
# Requirement already satisfied: numpy>=1.26.2 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (2.0.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from openai) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from openai) (0.9.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.11/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.11/dist-packages (from openai) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /usr/local/lib/python3.11/dist-packages (from openai) (4.13.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.4.3)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.19.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.11/dist-packages (from anyio<5,>=3.5.0->openai) (3.10)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/lib/python3.11/dist-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (0.9.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->openai) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->openai) (1.0.8)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.55->langchain) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.55->langchain) (24.2)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.17->langchain) (3.10.16)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.17->langchain) (0.23.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.1 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.33.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in /usr/local/lib/python3.11/dist-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community) (1.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain) (2.3.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from SQLAlchemy<3,>=1.4->langchain) (3.2.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.11/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.55->langchain) (3.0.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community) (1.1.0)
# Requirement already satisfied: langchain-google-genai in /usr/local/lib/python3.11/dist-packages (2.1.3)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from langchain-google-genai) (1.2.0)
# Requirement already satisfied: google-ai-generativelanguage<0.7.0,>=0.6.16 in /usr/local/lib/python3.11/dist-packages (from langchain-google-genai) (0.6.17)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.52 in /usr/local/lib/python3.11/dist-packages (from langchain-google-genai) (0.3.55)
# Requirement already satisfied: pydantic<3,>=2 in /usr/local/lib/python3.11/dist-packages (from langchain-google-genai) (2.11.3)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1 in /usr/local/lib/python3.11/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.16->langchain-google-genai) (2.24.2)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1 in /usr/local/lib/python3.11/dist-packages (from google-ai-generativelanguage<0.7.0,>=0.6.16->langchain-google-genai) (2.38.0)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /usr/local/lib/python3.11/dist-packages (from google-ai-generativelanguage<0.7.0,>=0.6.16->langchain-google-genai) (1.26.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2 in /usr/local/lib/python3.11/dist-packages (from google-ai-generativelanguage<0.7.0,>=0.6.16->langchain-google-genai) (5.29.4)
# Requirement already satisfied: langsmith<0.4,>=0.1.125 in /usr/local/lib/python3.11/dist-packages (from langchain-core<0.4.0,>=0.3.52->langchain-google-genai) (0.3.31)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.11/dist-packages (from langchain-core<0.4.0,>=0.3.52->langchain-google-genai) (9.1.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.11/dist-packages (from langchain-core<0.4.0,>=0.3.52->langchain-google-genai) (1.33)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.11/dist-packages (from langchain-core<0.4.0,>=0.3.52->langchain-google-genai) (6.0.2)
# Requirement already satisfied: packaging<25,>=23.2 in /usr/local/lib/python3.11/dist-packages (from langchain-core<0.4.0,>=0.3.52->langchain-google-genai) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in /usr/local/lib/python3.11/dist-packages (from langchain-core<0.4.0,>=0.3.52->langchain-google-genai) (4.13.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=2->langchain-google-genai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.1 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=2->langchain-google-genai) (2.33.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=2->langchain-google-genai) (0.4.0)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /usr/local/lib/python3.11/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.16->langchain-google-genai) (1.70.0)
# Requirement already satisfied: requests<3.0.0,>=2.18.0 in /usr/local/lib/python3.11/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.16->langchain-google-genai) (2.32.3)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in /usr/local/lib/python3.11/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.16->langchain-google-genai) (1.71.0)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in /usr/local/lib/python3.11/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.16->langchain-google-genai) (1.71.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<0.7.0,>=0.6.16->langchain-google-genai) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<0.7.0,>=0.6.16->langchain-google-genai) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.11/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<0.7.0,>=0.6.16->langchain-google-genai) (4.9.1)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.11/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.52->langchain-google-genai) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.52->langchain-google-genai) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.52->langchain-google-genai) (3.10.16)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.52->langchain-google-genai) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.52->langchain-google-genai) (0.23.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.52->langchain-google-genai) (4.9.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.52->langchain-google-genai) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.52->langchain-google-genai) (1.0.8)
# Requirement already satisfied: idna in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.52->langchain-google-genai) (3.10)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.52->langchain-google-genai) (0.14.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.11/dist-packages (from pyasn1-modules>=0.2.1->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<0.7.0,>=0.6.16->langchain-google-genai) (0.6.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.16->langchain-google-genai) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.16->langchain-google-genai) (2.3.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.52->langchain-google-genai) (1.3.1)
# Requirement already satisfied: openai in /usr/local/lib/python3.11/dist-packages (1.75.0)
# Requirement already satisfied: datasets in /usr/local/lib/python3.11/dist-packages (3.5.0)
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.11/dist-packages (0.30.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (1.6.1)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from openai) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from openai) (0.9.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.11/dist-packages (from openai) (2.11.3)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.11/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.11/dist-packages (from openai) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /usr/local/lib/python3.11/dist-packages (from openai) (4.13.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from datasets) (3.18.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from datasets) (2.0.2)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.3.8)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.11/dist-packages (from datasets) (2.32.3)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.11/dist-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2024.12.0,>=2023.1.0 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]<=2024.12.0,>=2023.1.0->datasets) (2024.12.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from datasets) (3.11.15)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from datasets) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from datasets) (6.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.14.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.11/dist-packages (from anyio<5,>=3.5.0->openai) (3.10)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (6.4.3)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.19.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->openai) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->openai) (1.0.8)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.1 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->openai) (2.33.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->openai) (0.4.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (2.3.0)

# %% [markdown]
# # Generate training data (Done By Zhang Jianyu)
# The first step of the assignment is generating synthetic question-answer pairs which can be used for finetuning an LLM model.
# Use the Google AI studio with the Gemini models to create -high-quality QA training data.

# %%
# !pip install -U langchain langchain-community openai

import os
import json
from langchain_community.chat_models import ChatOpenAI
from langchain.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain.schema.runnable import RunnableSequence

# Set your OpenAI API Key
os.environ["OPENAI_API_KEY"] = ""

# Prompt template
prompt = PromptTemplate(
    input_variables=["category"],
    template="List 3 items in the category of {category} and return them in a JSON array format. Respond only with the JSON."
)

# OpenAI LLM
llm = ChatOpenAI(model_name="gpt-4", temperature=0.7)

# Use StrOutputParser + json.loads manually
def json_parser(output_str):
    try:
        return json.loads(output_str)
    except json.JSONDecodeError:
        return {"error": "Could not parse JSON", "raw": output_str}

chain = RunnableSequence(prompt | llm | StrOutputParser() | json_parser)

# Run
response = chain.invoke({"category": "fruits"})
print(response)
# Out:
# Requirement already satisfied: langchain in /usr/local/lib/python3.11/dist-packages (0.3.24)
# Requirement already satisfied: langchain-community in /usr/local/lib/python3.11/dist-packages (0.3.22)
# Requirement already satisfied: openai in /usr/local/lib/python3.11/dist-packages (1.75.0)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.55 in /usr/local/lib/python3.11/dist-packages (from langchain) (0.3.55)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.8 in /usr/local/lib/python3.11/dist-packages (from langchain) (0.3.8)
# Requirement already satisfied: langsmith<0.4,>=0.1.17 in /usr/local/lib/python3.11/dist-packages (from langchain) (0.3.31)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.11/dist-packages (from langchain) (2.11.3)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.11/dist-packages (from langchain) (2.0.40)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.11/dist-packages (from langchain) (2.32.3)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.11/dist-packages (from langchain) (6.0.2)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (3.11.15)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (9.1.2)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (2.9.1)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (0.4.0)
# Requirement already satisfied: numpy>=1.26.2 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (2.0.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from openai) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from openai) (0.9.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.11/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.11/dist-packages (from openai) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /usr/local/lib/python3.11/dist-packages (from openai) (4.13.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.4.3)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.19.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.11/dist-packages (from anyio<5,>=3.5.0->openai) (3.10)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/lib/python3.11/dist-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (0.9.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->openai) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->openai) (1.0.8)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.55->langchain) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.55->langchain) (24.2)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.17->langchain) (3.10.16)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.17->langchain) (0.23.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.1 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.33.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in /usr/local/lib/python3.11/dist-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community) (1.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain) (2.3.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from SQLAlchemy<3,>=1.4->langchain) (3.2.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.11/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.55->langchain) (3.0.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community) (1.1.0)
# <ipython-input-5-6992a9bd62da>:20: LangChainDeprecationWarning: The class `ChatOpenAI` was deprecated in LangChain 0.0.10 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-openai package and should be used instead. To use it run `pip install -U :class:`~langchain-openai` and import as `from :class:`~langchain_openai import ChatOpenAI``.
#   llm = ChatOpenAI(model_name="gpt-4", temperature=0.7)
# ['Apple', 'Banana', 'Cherry']

# %% [markdown]
# ## Generate topics
# When generating data, it is often helpful to guide the generation process through some hierachical structure.
# Before we create question-answer pairs, let's generate some topics which the questions should be about.

# %%
import json
from langchain_community.chat_models import ChatOpenAI
from langchain.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain.schema.runnable import RunnableSequence

# Set your OpenAI key in the environment (already done above if reused)
# os.environ["OPENAI_API_KEY"] = "your-openai-key-here"

# Define OpenAI LLM
llm = ChatOpenAI(model_name="gpt-4", temperature=0.7)

# Define prompt template
topic_prompt = PromptTemplate(
    input_variables=["num"],
    template=(
        "Generate a list of {num} topics that prospective university students might care about. "
        "Focus especially on those relevant for students considering studying at SUTD. "
        "Return only a JSON array of strings."
    )
)

# Output parser that returns raw string
output_parser = StrOutputParser()

# Create chain
topic_chain = RunnableSequence(topic_prompt | llm | output_parser)

# Define function to use the chain
def generate_topics(n=20):
    """
    Generate a list of `n` topics using OpenAI model.
    Returns:
        list of str: Parsed JSON array of topic strings.
    """
    raw = topic_chain.invoke({"num": n}).strip()

    # Clean markdown formatting if present
    if raw.startswith("```json"):
        raw = raw.replace("```json", "").replace("```", "").strip()

    try:
        topics = json.loads(raw)
        if not isinstance(topics, list) or not all(isinstance(t, str) for t in topics):
            raise ValueError("Generated content is not a list of strings.")
        return topics
    except Exception as e:
        print("Failed to parse response as JSON:", e)
        print("Raw response:", raw)
        return []

# %%
# test topic generation
print(generate_topics(3))
# Out:
# ["SUTD's Collaboration with MIT and Zhejiang University", "SUTD's Unique Curriculum Structure and Pedagogy", 'Accommodation and Living Conditions at SUTD']

# %%
import os
import json

# Define file path
TOPIC_FILE = "topics.json"

def load_or_generate_topics():
    """
    Load a clean list of topics from file if it exists.
    If the file contains invalid formatting (e.g., markdown markers),
    it will be cleaned and parsed properly.
    If the file does not exist or parsing fails, new topics will be generated and saved.
    Returns:
        list of str: A list of topic strings.
    """
    topics = []

    if os.path.exists(TOPIC_FILE):
        with open(TOPIC_FILE, "r", encoding="utf-8") as f:
            raw = f.read()

        # Remove markdown formatting like ```json and ```
        cleaned = raw.replace("```json", "").replace("```", "").strip()

        try:
            topics = json.loads(cleaned)
            if not isinstance(topics, list) or not all(isinstance(t, str) for t in topics):
                raise ValueError("Invalid format: topics must be a list of strings.")
            print("✅ Loaded and cleaned topics from file.")
        except Exception as e:
            print(f"⚠️ Failed to parse {TOPIC_FILE}: {e}")
            topics = []

    if not topics:
        # Generate new topics if file is missing or invalid
        topics = generate_topics(20)
        with open(TOPIC_FILE, "w", encoding="utf-8") as f:
            json.dump(topics, f, ensure_ascii=False, indent=2)
        print("🆕 Generated and saved new topics.")

    return topics

# Example usage
topics = load_or_generate_topics()
print(json.dumps(topics, ensure_ascii=False, indent=2))
# Out:
# ✅ Loaded and cleaned topics from file.
# [
#   "Design-Centric Curriculum",
#   "Hands-on Learning Opportunities",
#   "Interdisciplinary Programs",
#   "Technology and Innovation Ecosystem",
#   "Career Prospects in Emerging Fields",
#   "Industry Collaboration and Internships",
#   "Global Exchange Programs",
#   "Research Opportunities for Undergraduates",
#   "Scholarships and Financial Aid",
#   "Campus Facilities and Resources",
#   "Student Life and Community",
#   "Entrepreneurship and Startup Incubation",
#   "Faculty Expertise and Research Areas",
#   "Location and Accessibility",
#   "Admissions Requirements and Process",
#   "Diversity and Inclusion on Campus",
#   "Sustainability Initiatives",
#   "Student Support Services (e.g., counseling, academic advising)",
#   "Alumni Network and Mentorship",
#   "Focus on Digital Manufacturing and Design"
# ]

# %% [markdown]
# ## Generate questions (Done By Zhang Jianyu)
# Now generate a set of questions about each topic

# %%
# QUESTION: Create a function 'generate_questions' which generates quetions about a given topic.
# Generate a list of 10 questions per topics. In total you should have 200 questions.
#

#--- ADD YOUR SOLUTION HERE (20 points)---

# Define prompt template for question generation
question_prompt = PromptTemplate(
    input_variables=["topic", "num"],
    template=(
        "Generate {num} questions that a prospective university student might ask about the topic '{topic}'. "
        "Focus on aspects relevant to students considering studying at SUTD. "
        "Return only a JSON array of strings, no explanations or extra text."
    )
)

# Create runnable chain
question_chain = question_prompt | llm

# Define function to generate questions
def generate_questions(topic, n=10):
    """Generate `n` questions about a given topic using Gemini"""
    response = question_chain.invoke({"topic": topic, "num": n})
    try:
        return json.loads(response.content)  # convert JSON string to Python list
    except json.JSONDecodeError:
        print("JSON decode failed. Raw output:")
        print(response.content)
        return []

# %%
# test it
print(generate_questions("Academic Reputation and Program Quality", 3))
# Out:
# ["How does SUTD's interdisciplinary curriculum contribute to its academic reputation and the quality of its programs, specifically in terms of preparing graduates for emerging industries?", 'What metrics or rankings does SUTD use to assess and maintain the quality of its academic programs, and how do these compare to other leading universities in Singapore and globally?', 'Beyond coursework, what opportunities are available at SUTD for undergraduate students to engage in research, design projects, or other activities that enhance the academic rigor and reputation of their chosen program?']

# %%
# # QUESTION: Now let's put it together and generate 10 questions for each topic. Save the questions in a local file.

#--- ADD YOUR SOLUTION HERE (20 points)---

# Define file path
from langchain.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain.schema.runnable import RunnableSequence

# Define prompt template for question generation
question_prompt = PromptTemplate(
    input_variables=["topic", "num"],
    template=(
        "Generate {num} questions that a prospective university student might ask about the topic '{topic}'. "
        "Focus on aspects relevant to students considering studying at SUTD. "
        "Return only a JSON array of strings, no explanations or extra text."
    )
)

# Define output parser
output_parser = StrOutputParser()

# Build chain with OpenAI LLM
question_chain = RunnableSequence(question_prompt | llm | output_parser)

# Define function to generate questions
def generate_questions(topic, n=10):
    """Generate `n` questions about a given topic using OpenAI"""
    raw = question_chain.invoke({"topic": topic, "num": n}).strip()

    # Handle markdown-wrapped JSON
    if raw.startswith("```json"):
        raw = raw.replace("```json", "").replace("```", "").strip()

    try:
        questions = json.loads(raw)
        if not isinstance(questions, list) or not all(isinstance(q, str) for q in questions):
            raise ValueError("Response is not a list of strings.")
        return questions
    except Exception as e:
        print("⚠️ Failed to parse questions as JSON:", e)
        print("Raw output:\n", raw)
        return []

# %% [markdown]
# ## Generate Answers (Done By Liu Yu)
#
# Now create answers for the questions.
#
# You can use the Google AI Studio Gemini model (assuming that they are good enough to generate good answers), your RAG system from assignment 3 or any other method you choose to generate answers for your question dataset.
#
# Note: it is normal that some LLM calls fail, even with retry, so maybe you end up with less than 200 QA pairs but it should be at least 160 QA pairs.

# %%
# QUESTION: Generate answers to al your questions using Gemini, your SUTD RAG system or any other method.
# Split your dataset in to 80% training and 20% test dataset.
# Store all questions and answer pairs in a huggingface dataset `sutd_qa_dataset` and push it to your Huggingface hub.

#--- ADD YOUR SOLUTION HERE (40 points)---

# Set API keys
client = OpenAI(api_key="")
login("")  

# Load question data
with open("questions.json") as qf:
    questions_data = json.load(qf)

with open("topics.json") as tf:
    topics = json.load(tf)

qa_pairs = []
for topic in topics:
    for question in questions_data[topic]:
        qa_pairs.append({"topic": topic, "question": question})

df = pd.DataFrame(qa_pairs)

# Generate answers using OpenAI
answers = []
for i, row in df.iterrows():
    prompt = f"Answer this question as if you are a SUTD admissions or faculty staff. Limit your response to **no more than 100 words**:\n\n{row['question']}"
    try:
        response = client.chat.completions.create(
            model="gpt-3.5-turbo",
            messages=[
                {"role": "system", "content": "You are a helpful assistant for SUTD university answering prospective student questions."},
                {"role": "user", "content": prompt}
            ],
            temperature=0.7
        )
        answer = response.choices[0].message.content.strip()
        print(f"[{i}] {row['question']}\n→ {answer}\n")
    except Exception as e:
        answer = None
        print(f"❌ Failed at {i}: {e}")
    answers.append(answer)
    time.sleep(1.5)

# STEP 6: Clean failed entries
df["answer"] = answers
df = df[df["answer"].notnull()].reset_index(drop=True)

# STEP 7: Train/test split
train_df, test_df = train_test_split(df, test_size=0.2, random_state=42)

# STEP 8: Convert to HF Dataset
train_dataset = Dataset.from_pandas(train_df)
test_dataset = Dataset.from_pandas(test_df)

qa_dataset = DatasetDict({
    "train": train_dataset,
    "test": test_dataset
})

# STEP 9: Push to Hugging Face Hub
qa_dataset.push_to_hub("")

# access the dataset via: ""
# Out:
# [0] How does SUTD's design-centric curriculum differ from traditional engineering programs?
# → SUTD's design-centric curriculum integrates engineering principles with design thinking, emphasizing creativity, innovation, and human-centered solutions. Students learn to approach problems holistically, considering technical, social, and environmental aspects. This approach fosters interdisciplinary collaboration and equips students with the skills to address complex real-world challenges effectively. Traditional engineering programs often focus primarily on technical skills and theory. At SUTD, students not only gain technical expertise but also develop a deep understanding of the impact of their designs on society and the environment.
#
# [1] What specific design thinking methodologies are taught and practiced throughout the curriculum?
# → At SUTD, we integrate design thinking methodologies such as user-centered design, prototyping, and iteration across various courses. Our curriculum emphasizes a hands-on, project-based approach where students apply these methodologies to solve real-world problems. Additionally, our collaboration with MIT ensures exposure to cutting-edge design thinking practices.
#
# [2] Can you provide examples of real-world projects students undertake in the design-centric curriculum?
# → Certainly! At SUTD, students work on a wide range of real-world projects such as designing sustainable transportation systems, creating smart healthcare solutions, developing innovative products for social impact, and much more. These projects often involve collaboration with industry partners, government agencies, and non-profit organizations to address pressing societal challenges. Students gain valuable hands-on experience, applying design thinking principles to create impactful and practical solutions.
#
# [3] How does the design-centric approach prepare students for careers in emerging fields like AI, robotics, and sustainability?
# → At SUTD, our design-centric approach equips students with a strong foundation in interdisciplinary problem-solving, critical thinking, and creativity. This prepares students to tackle complex challenges in emerging fields like AI, robotics, and sustainability by fostering innovation and adaptability. Through project-based learning and real-world applications, students develop technical skills alongside the ability to design sustainable solutions that address societal needs, making them well-prepared to excel in these rapidly evolving industries.
#
# [4] What opportunities exist for interdisciplinary collaboration within the design-centric framework?
# → At SUTD, students have the opportunity to engage in interdisciplinary collaboration through our unique curriculum that integrates design, engineering, and technology. Our design-centric framework encourages students to work across different disciplines, fostering creativity and innovation. Students can participate in projects, competitions, and research initiatives that require collaboration with peers from various backgrounds, providing a holistic learning experience and preparing them for real-world challenges.
#
# [5] How are design communication and presentation skills developed throughout the program?
# → Design communication and presentation skills are developed throughout the SUTD program through a combination of hands-on projects, design studios, presentations, critiques, and workshops. Students are encouraged to actively engage in design thinking, visual communication, and storytelling to effectively communicate their ideas. Faculty members provide guidance and feedback to help students improve their skills over time. Additionally, students have opportunities to participate in design competitions, exhibitions, and industry collaborations to further enhance their communication and presentation abilities.
#
# [6] What is the balance between theoretical knowledge and practical application in design-centric learning?
# → At SUTD, we emphasize a balanced approach between theoretical knowledge and practical application in design-centric learning. Students engage in hands-on projects, design challenges, and real-world internships to apply concepts learned in the classroom. This approach ensures that students not only understand the theoretical foundations but also gain valuable practical experience in solving complex design problems. Our curriculum is designed to cultivate a deep understanding of design principles while nurturing creativity and innovation through hands-on experiences.
#
# [7] How does SUTD assess student performance within the design-centric curriculum?
# → At SUTD, student performance in the design-centric curriculum is assessed through a variety of methods such as project work, presentations, examinations, and peer evaluations. Students are evaluated based on their ability to apply design thinking, problem-solving skills, creativity, and collaboration in their projects. Continuous feedback is provided to help students improve and excel in their studies.
#
# [8] What support resources are available to students navigating the design process, such as workshops, mentors, or specialized software?
# → At SUTD, we provide various support resources to students in the design process. These include design workshops, mentorship programs with industry professionals, access to specialized design software, and collaborative project spaces. Our faculty and staff are also available to guide and assist students throughout their design projects. Additionally, we offer design-related courses and extracurricular activities to further enhance students' skills and knowledge in design.
#
# [9] Are there opportunities to tailor the design-centric curriculum based on individual interests or career goals?
# → Yes, at SUTD, students have the flexibility to customize their education through elective courses, specializations, and research projects that align with their interests and career goals. Our design-centric curriculum allows students to explore various interdisciplinary fields and develop skills tailored to their individual aspirations, ensuring a well-rounded education that prepares them for their desired career paths.
#
# [10] What types of hands-on projects are integrated into the curriculum at SUTD, and how frequently do they occur?
# → At SUTD, hands-on projects are integrated into the curriculum across all courses. Students work on design projects, prototypes, and real-world challenges regularly, with a focus on practical application of concepts learned in class. These projects occur frequently throughout the semester, allowing students to develop critical problem-solving and design skills.
#
# [11] Can you provide specific examples of hands-on projects students have completed in my program of interest (e.g., Architecture and Sustainable Design, Engineering Product Development, Engineering Systems and Design, or Information Systems Technology and Design)?
# → Certainly! In the Architecture and Sustainable Design program, students have completed hands-on projects such as designing and building sustainable structures using recycled materials, creating interactive installations to promote environmental awareness, and collaborating with industry partners to develop sustainable building prototypes. These projects allow students to apply their knowledge in real-world contexts and gain practical experience in sustainable design practices.
#
# [12] What specialized facilities and equipment are available for students to use during hands-on projects (e.g., labs, workshops, maker spaces)?
# → SUTD provides state-of-the-art facilities like the Fabrication Lab, which houses 3D printers, laser cutters, and CNC machines. The Prototyping Lab offers tools for electronics, woodworking, and metalworking. Students also have access to the Robotics Lab, where they can experiment with various robots and sensors. These facilities support hands-on learning and empower students to bring their ideas to life.
#
# [13] How does SUTD's design-centric curriculum incorporate hands-on learning into the problem-solving process?
# → SUTD's design-centric curriculum integrates hands-on learning through project-based courses, design studios, and maker culture. Students engage in real-world projects, collaborate with industry partners, and utilize state-of-the-art facilities such as labs and workshops. This approach enables students to apply theoretical knowledge to solve complex problems, develop practical skills, and gain valuable experience in design thinking and innovation.
#
# [14] Are there opportunities to collaborate with industry partners on real-world projects through internships, research, or capstone experiences?
# → Yes, at SUTD, we offer various opportunities for students to collaborate with industry partners on real-world projects. These include internships, research projects, and capstone experiences where students work closely with industry experts to gain practical experience and insights. Our strong network of industry partners allows students to apply their knowledge and skills in real-world settings, preparing them for future careers in their respective fields.
#
# [15] How do hands-on projects at SUTD prepare students for the challenges and demands of their chosen careers?
# → Hands-on projects at SUTD provide students with practical experience, problem-solving skills, and teamwork abilities essential for their chosen careers. By working on real-world projects, students learn to apply theoretical knowledge in practical settings, develop critical thinking skills, and adapt to complex challenges. This hands-on approach equips students with the necessary skills and mindset to excel in their future careers, where they will be required to innovate, collaborate, and tackle real-world problems effectively.
#
# [16] What is the typical student-to-faculty ratio in hands-on learning environments, and how does this facilitate individual attention and mentorship?
# → The typical student-to-faculty ratio in hands-on learning environments at SUTD is around 10:1. This low ratio allows for personalized attention and mentorship, enabling faculty members to provide individual guidance to students as they work on projects and engage in practical learning experiences. Students benefit from close interactions with faculty, fostering a collaborative and supportive environment for their academic and personal growth.
#
# [17] Are there opportunities to pursue independent research projects or develop personal projects with faculty support and access to resources?
# → Yes, at SUTD, students have the opportunity to pursue independent research projects and develop personal projects with faculty support and access to resources. Our faculty members are actively involved in research and are committed to guiding and supporting students in their projects. Students can also leverage various resources and facilities on campus to further enhance their projects and research endeavors.
#
# [18] Does SUTD offer design competitions, hackathons, or other events that encourage hands-on learning and innovation?
# → Yes, SUTD organizes various design competitions, hackathons, and other events to promote hands-on learning and innovation. These events provide students with opportunities to apply their skills and knowledge in practical settings, collaborate with peers, and gain real-world experience. Students have the chance to showcase their creativity, problem-solving abilities, and teamwork skills while working on innovative projects that address real-world challenges.
#
# [19] How does SUTD assess and evaluate student performance in hands-on projects, and what feedback mechanisms are in place to support student learning and development?
# → At SUTD, student performance in hands-on projects is evaluated through criteria such as creativity, problem-solving, and technical proficiency. Feedback mechanisms include peer evaluations, instructor feedback, and project reviews to support student learning and development. Additionally, students have access to resources such as workshops, tutorials, and one-on-one consultations with faculty members to help them improve and excel in their projects.
#
# [20] What interdisciplinary programs does SUTD offer, and how do they differ from traditional single-major programs?
# → SUTD offers interdisciplinary programs such as Engineering Systems and Design (ESD), Information Systems Technology and Design (ISTD), and Architecture and Sustainable Design (ASD). These programs integrate multiple disciplines to provide a holistic approach to problem-solving, preparing students to tackle complex real-world challenges. Unlike traditional single-major programs, interdisciplinary programs at SUTD emphasize collaboration, creativity, and innovation across different fields, equipping students with a broader skill set and perspective for addressing multifaceted issues in today's dynamic world.
#
# [21] How does SUTD's interdisciplinary curriculum prepare students for careers in emerging fields?
# → SUTD's interdisciplinary curriculum equips students with a well-rounded skill set, blending design thinking with technology and innovation. This approach fosters creativity, problem-solving abilities, and adaptability, essential in emerging fields. Students engage in hands-on projects, industry collaborations, and research opportunities, preparing them to tackle complex challenges in areas like AI, robotics, and sustainability. The emphasis on collaboration across disciplines ensures graduates are well-prepared for the dynamic demands of evolving industries.
#
# [22] Can you provide examples of real-world projects or research opportunities that students in interdisciplinary programs at SUTD have undertaken?
# → SUTD students in interdisciplinary programs have worked on various impactful projects, such as designing sustainable housing solutions, developing smart healthcare devices, and creating innovative urban planning strategies. They have also engaged in cutting-edge research in areas like artificial intelligence for social good, sustainable energy systems, and human-centered design. These experiences equip students with the skills and knowledge to address complex real-world challenges across different disciplines.
#
# [23] What is the typical student experience like in an interdisciplinary program at SUTD, and how does it foster collaboration and innovation?
# → At SUTD, interdisciplinary programs provide students with a holistic education, integrating various disciplines to solve complex real-world problems. Students engage in project-based learning, working in diverse teams to design innovative solutions. This collaborative approach encourages the exchange of ideas, perspectives, and skills, fostering creativity and innovation. Through hands-on experiences and industry projects, students develop a deep understanding of interdisciplinary collaboration, preparing them to thrive in a dynamic, interconnected world.
#
# [24] How does SUTD support students in navigating the complexities of an interdisciplinary curriculum and choosing a specialization?
# → SUTD supports students in navigating the interdisciplinary curriculum through personalized academic advising, project-based learning, and industry collaborations. Students receive guidance from faculty advisors and career counselors to explore various specializations. Additionally, SUTD offers a flexible curriculum structure that allows students to tailor their education to align with their interests and career goals. Through hands-on projects and internships, students gain practical experience to make informed decisions about their specialization.
#
# [25] What are the career prospects for graduates of SUTD's interdisciplinary programs, and what kind of industries do they typically enter?
# → Graduates of SUTD's interdisciplinary programs have diverse career prospects in industries such as technology, engineering, design, and innovation. They are equipped with a unique skill set that enables them to work in various fields including urban planning, healthcare, sustainability, and advanced manufacturing. Our alumni have been successful in roles such as product designers, data analysts, project managers, and research scientists in both local and global companies. The strong foundation in interdisciplinary learning at SUTD prepares graduates for dynamic and evolving industries.
#
# [26] How does SUTD's design-centric approach influence the structure and delivery of its interdisciplinary programs?
# → SUTD's design-centric approach is integrated into the structure of its interdisciplinary programs by emphasizing the importance of interdisciplinary collaboration, creativity, and human-centered design in solving complex real-world problems. This influences the delivery of programs through a project-based learning approach, where students work on hands-on design projects that cut across multiple disciplines. This unique approach fosters a holistic understanding of problems and encourages innovative solutions that consider both technical and human factors.
#
# [27] Are there opportunities for students in interdisciplinary programs to pursue minors or specializations within or outside their chosen field?
# → Yes, at SUTD, students in interdisciplinary programs have the flexibility to pursue minors or specializations within or outside their chosen field. This allows students to tailor their academic experience to their interests and career goals, enhancing their learning experience and skill set.
#
# [28] How does SUTD facilitate interaction between students from different disciplines within interdisciplinary programs?
# → SUTD facilitates interaction between students from different disciplines within interdisciplinary programs through collaborative projects, design-centric curriculum, and shared spaces. Students work in multi-disciplinary teams on real-world projects, allowing them to learn from each other's expertise and perspectives. Moreover, the university's open-studio environment and design workshops encourage constant interaction and knowledge exchange among students from various disciplines.
#
# [29] What support systems are in place at SUTD to help students in interdisciplinary programs succeed academically and professionally?
# → At SUTD, we provide various support systems to help students in interdisciplinary programs excel. This includes dedicated academic advisors, peer mentoring programs, career counseling services, and industry partnerships for real-world experience. Our innovative curriculum and collaborative environment also foster critical thinking and problem-solving skills essential for success in a rapidly evolving world.
#
# [30] How does SUTD's curriculum foster collaboration and innovation within its technology and innovation ecosystem?
# → SUTD's curriculum is designed with a strong emphasis on interdisciplinary projects, where students work in teams on real-world challenges. This approach encourages collaborative problem-solving and innovation within our technology and innovation ecosystem. Additionally, our unique curriculum integrates design thinking, entrepreneurship, and technology, providing students with a holistic understanding and skill set to drive innovation in various fields.
#
# [31] What opportunities exist for students to engage with industry partners and startups through SUTD's ecosystem?
# → At SUTD, students have various opportunities to engage with industry partners and startups. These include industry-sponsored projects, internships, networking events, and collaborations on research projects. Our strong connections with industry leaders and startups provide students with real-world experience, mentorship, and potential career opportunities. Additionally, our vibrant ecosystem fosters entrepreneurship through programs like the SUTD Technology Entrepreneurship Programme (STEP) and funding support for student-led startups.
#
# [32] How does SUTD support student-led technology startups and projects?
# → SUTD supports student-led technology startups and projects through various channels, such as the SUTD Entrepreneurship Centre, which provides mentorship, funding opportunities, and networking events. Additionally, SUTD's curriculum integrates real-world projects and industry collaborations, enabling students to develop entrepreneurial skills and apply their knowledge in practical settings. The university also encourages participation in hackathons, competitions, and innovation challenges to further nurture entrepreneurial spirit among students.
#
# [33] What specific resources and facilities within SUTD's ecosystem are available to students interested in developing new technologies?
# → At SUTD, students interested in developing new technologies have access to state-of-the-art facilities such as the Digital Manufacturing and Design Centre, Advanced Architecture Laboratory, and Prototyping Lab. Additionally, they can leverage resources like the SUTD-MIT International Design Centre and collaboration opportunities with industry partners for hands-on experience and innovation.
#
# [34] How does SUTD's focus on design thinking integrate with its technology and innovation ecosystem?
# → SUTD's focus on design thinking integrates seamlessly with its technology and innovation ecosystem by placing a strong emphasis on interdisciplinary collaboration and problem-solving skills. Through project-based learning and hands-on experiences, students are equipped with the tools to tackle real-world challenges with creative solutions. This approach fosters a culture of innovation and entrepreneurship, preparing students to be versatile leaders in the rapidly evolving tech industry.
#
# [35] What role do research and development play within SUTD's technology and innovation ecosystem, and how can students get involved?
# → Research and development are integral to SUTD's technology and innovation ecosystem, driving cutting-edge advancements. Students can engage in research through various avenues such as Undergraduate Research Opportunities Programme (UROP), research internships, and projects with faculty. These opportunities allow students to work alongside experts, contribute to real-world projects, and gain valuable experience in their chosen field.
#
# [36] Can you provide examples of successful projects or startups that have emerged from SUTD's ecosystem?
# → Certainly! Some successful projects and startups that have emerged from SUTD's ecosystem include Volocopter, a company that specializes in developing autonomous air taxis, and Gilmour Space Technologies, a startup that focuses on developing low-cost hybrid rockets for launching small satellites into space. These examples showcase the innovative and entrepreneurial spirit of our students and alumni.
#
# [37] How does SUTD's location in Singapore contribute to its technology and innovation ecosystem and benefit students?
# → SUTD's location in Singapore provides students with access to a vibrant technology and innovation ecosystem. Students can engage with industry partners, government agencies, and research institutions for real-world projects and internships. The city-state's status as a global innovation hub offers students opportunities to network, collaborate, and gain insights from leading experts in various fields. Additionally, Singapore's strategic location in Asia allows students to tap into the region's diverse markets and emerging technologies, enhancing their global perspectives and competitiveness.
#
# [38] What are the career pathways and opportunities available to graduates leveraging SUTD's technology and innovation ecosystem?
# → SUTD graduates are well-equipped for diverse career pathways in technology and innovation sectors such as engineering, design, data science, and entrepreneurship. Our strong industry partnerships and emphasis on hands-on learning provide opportunities in research, startups, multinational corporations, and government agencies. Graduates have excelled in fields like robotics, sustainable architecture, urban planning, and more. Our alumni network and supportive ecosystem ensure access to a wide range of career opportunities.
#
# [39] How does SUTD's technology and innovation ecosystem prepare students for the challenges and opportunities of a rapidly evolving technological landscape?
# → At SUTD, our unique interdisciplinary curriculum, industry collaborations, and hands-on projects equip students with the skills and mindset needed to thrive in a rapidly evolving technological landscape. Through our design-centric approach, students learn to tackle complex problems, think critically, and innovate solutions. Our strong ties with industry partners provide real-world exposure and opportunities for students to work on cutting-edge projects. Additionally, our emphasis on entrepreneurship and design thinking empowers students to create impactful solutions and adapt to the ever-changing technology landscape.
#
# [40] What emerging fields are SUTD graduates particularly well-suited for, given the university's focus on design and technology?
# → SUTD graduates are well-suited for emerging fields such as artificial intelligence, data science, urban planning, and sustainable design. Their unique combination of design thinking and technological expertise prepares them to tackle complex challenges and innovate in these rapidly evolving industries.
#
# [41] How does SUTD's curriculum prepare students for the interdisciplinary nature of many emerging fields?
# → SUTD's curriculum is designed with a strong focus on interdisciplinary learning, combining technology, design, and innovation. Students engage in hands-on projects, collaborative work, and real-world problem-solving, preparing them for the complexities of emerging fields. Our emphasis on design thinking, communication skills, and teamwork equips students to navigate diverse perspectives and adapt to the dynamic nature of interdisciplinary work, ensuring they are well-prepared for the challenges of the future.
#
# [42] Does SUTD offer specific programs, minors, or specializations focused on high-growth areas like AI, robotics, or sustainable energy?
# → Yes, SUTD offers specialized programs, minors, and specializations in high-growth areas such as Artificial Intelligence (AI), Robotics, and Sustainable Energy. Our curriculum is designed to provide students with a strong foundation and practical experience in these cutting-edge fields, preparing them for careers in industries driving technological innovation and sustainability.
#
# [43] What career support services does SUTD provide to help students explore and secure positions in emerging fields, such as industry connections or specialized career counseling?
# → SUTD offers comprehensive career support services, including industry connections through partnerships with leading companies, specialized career counseling, networking events, workshops, and job fairs focused on emerging fields. Our career advisors help students navigate opportunities in various industries and provide guidance on securing positions aligned with their interests and skills.
#
# [44] Can you share examples of successful SUTD alumni who have launched careers in emerging fields?
# → Certainly! Some successful SUTD alumni who have launched careers in emerging fields include Tanmay Bakshi, a young AI expert who has worked with Google and Microsoft, and Joel Neoh, the founder of Fave, a prominent fintech startup. These alumni have demonstrated the impact of SUTD's innovative education in preparing students for cutting-edge industries.
#
# [45] How does SUTD foster entrepreneurship and innovation, particularly for students interested in creating their own ventures in emerging fields?
# → SUTD instills entrepreneurship and innovation through a unique curriculum emphasizing design thinking, technology, and business. Students have access to incubation programs, mentorship, and funding opportunities to develop their ventures. Our close industry partnerships and multidisciplinary approach also provide a fertile ground for students to explore emerging fields and bring their ideas to life.
#
# [46] What research opportunities are available to undergraduates at SUTD that relate to emerging fields?
# → At SUTD, undergraduates have access to various research opportunities in emerging fields through our Undergraduate Research Opportunities Programme (UROP). Students can work closely with faculty members on cutting-edge projects in areas such as artificial intelligence, robotics, sustainable design, and more. Additionally, our faculty members are actively engaged in research across a wide range of emerging fields, providing students with valuable mentorship and exposure to the latest developments in their chosen field of study.
#
# [47] How does SUTD adapt its curriculum to keep pace with the rapid evolution of emerging fields?
# → SUTD continuously reviews and updates its curriculum by collaborating with industry partners to ensure relevance to emerging fields. Faculty members incorporate real-world projects and industry challenges into coursework, enabling students to apply theoretical knowledge in practical settings. Additionally, SUTD's flexible modular system allows for quick adjustment of course content to reflect the latest developments in technology and design.
#
# [48] What partnerships does SUTD have with industry leaders in emerging fields, and how do these benefit students?
# → SUTD has strategic partnerships with industry leaders such as Dyson, Rolls-Royce, and Alibaba, providing students with real-world projects, internships, and mentorship opportunities. These collaborations expose students to cutting-edge technologies, industry best practices, and potential job prospects. By working closely with industry partners, students gain practical insights, hands-on experience, and valuable networking opportunities that enhance their employability and competitiveness in emerging fields.
#
# [49] What is the average starting salary and career trajectory for SUTD graduates entering emerging fields compared to more traditional sectors?
# → SUTD graduates entering emerging fields typically command competitive starting salaries, often exceeding those in traditional sectors. The career trajectory for these graduates in emerging fields is also promising, with opportunities for rapid advancement and growth in innovative industries. SUTD's unique interdisciplinary education equips students with the skills and knowledge to excel in dynamic and evolving sectors, setting them up for successful and fulfilling careers in the future.
#
# [50] What specific industries does SUTD collaborate with for research projects and internships?
# → SUTD collaborates with a wide range of industries for research projects and internships, including but not limited to technology, engineering, design, healthcare, finance, and sustainability sectors. Our partnerships with industry leaders provide students with valuable opportunities to gain real-world experience and make meaningful contributions to cutting-edge projects.
#
# [51] How does SUTD facilitate connections between students and industry partners for internship opportunities?
# → At SUTD, we have a strong network of industry partners who actively engage with our students through various platforms such as career fairs, networking events, and industry projects. Our Career Development Center also assists students in securing internships by providing resources, workshops, and one-on-one career coaching. Additionally, our curriculum is designed in collaboration with industry partners, ensuring that students are well-prepared for internships and future careers.
#
# [52] Can you provide examples of past successful industry collaborations and their impact on student learning?
# → Some examples of successful industry collaborations at SUTD include projects with companies like Dyson, BMW, and Rolls-Royce. These collaborations offer students real-world experience, access to cutting-edge technology, and networking opportunities. For instance, students working with Dyson developed innovative product designs, enhancing their problem-solving and design skills. Industry collaborations at SUTD provide valuable insights into industry practices, allowing students to apply their knowledge in practical settings and preparing them for future careers.
#
# [53] Are there opportunities for international internships through SUTD's industry network?
# → Yes, SUTD has a strong industry network that provides numerous opportunities for international internships. Our partnerships with global companies and organizations offer students the chance to gain valuable work experience abroad and expand their professional network on a global scale. Students can explore diverse internship opportunities in various countries through these connections.
#
# [54] Does SUTD offer support, such as workshops or mentorship, to help students secure internships?
# → Yes, SUTD provides support to help students secure internships through various workshops, career fairs, and mentorship programs. Our Career Development Center offers resources and guidance to assist students in finding internship opportunities that align with their interests and career goals. Additionally, students have access to industry connections and networking events to enhance their internship search.
#
# [55] How are internships integrated into the SUTD curriculum, and do they contribute to academic credit?
# → Internships are an integral part of the SUTD curriculum, providing real-world experience and industry exposure. Students can earn academic credits through internships by completing a minimum number of weeks in an approved organization. The credits earned contribute towards students' academic requirements, allowing them to gain practical experience while progressing in their studies.
#
# [56] What is the typical duration of an industry internship at SUTD, and when do they usually take place?
# → At SUTD, industry internships typically last for about 8 to 12 weeks. They usually take place during the students' summer break, which falls between the end of May and August. This allows students to gain practical work experience while still pursuing their academic studies.
#
# [57] Are there opportunities for students to work on real-world industry projects as part of their coursework outside of formal internships?
# → Yes, at SUTD, students have the opportunity to work on real-world industry projects through various avenues such as project-based courses, capstone projects, and collaborations with industry partners. These experiences allow students to apply their knowledge and skills in practical settings, preparing them for the demands of the industry.
#
# [58] How does SUTD ensure the quality and relevance of internship experiences offered to its students?
# → SUTD collaborates closely with industry partners to curate internship opportunities that align with our curriculum and industry needs. Our dedicated Career Development Center works with students to secure meaningful internships that provide valuable real-world experience. We also conduct regular evaluations and feedback sessions to ensure the quality and relevance of internship experiences.
#
# [59] What is the average success rate of SUTD students securing internships in their desired fields?
# → The average success rate of SUTD students securing internships in their desired fields is high, with many students successfully obtaining internships that align with their career goals. Our strong industry connections and emphasis on practical experience through our curriculum and programs contribute to this high success rate. Additionally, our Career Development Center provides support and resources to help students secure internships that suit their interests and aspirations.
#
# [60] What global exchange programs does SUTD offer, and with which partner universities?
# → SUTD offers global exchange programs with over 70 partner universities worldwide. Some of our partner universities include MIT, Stanford University, University of Tokyo, ETH Zurich, and Technion. These programs provide students with opportunities to immerse themselves in different cultures, gain diverse perspectives, and broaden their academic experience.
#
# [61] What are the eligibility criteria for SUTD students to participate in a global exchange program?
# → To be eligible for a global exchange program at SUTD, students must have completed at least one year of study, have a minimum Cumulative Grade Point Average (CGPA) of 3.5, and be in good academic standing. Additionally, students need to demonstrate strong communication skills, maturity, and the ability to adapt to new environments. Meeting these criteria ensures that students are well-prepared to make the most of their exchange experience and represent SUTD positively abroad.
#
# [62] How does the SUTD academic calendar align with the academic calendars of partner universities for exchange programs?
# → SUTD's academic calendar is designed to align with our partner universities for exchange programs. This ensures a seamless transition for students participating in exchange programs, allowing them to easily transfer credits and continue their academic progress. Our academic calendar is coordinated in advance with partner universities to facilitate a smooth exchange experience for all students involved.
#
# [63] What is the typical duration of a global exchange program at SUTD?
# → The typical duration of a global exchange program at SUTD is one semester, which is approximately 4 to 6 months. During this time, students have the opportunity to study at one of our partner universities around the world, gaining international exposure and expanding their academic horizons.
#
# [64] What financial aid or scholarship opportunities are available for SUTD students participating in exchange programs?
# → SUTD offers various scholarships and financial aid options for students participating in exchange programs, such as the SUTD Global Scholarship and the SUTD Study Abroad Financial Aid. These aim to support students in covering expenses related to exchange programs, including tuition fees, living expenses, and travel costs. Additionally, students can also explore external scholarships and funding opportunities to further support their exchange experience.
#
# [65] How do credits earned during a global exchange program transfer back to SUTD?
# → Credits earned during a global exchange program can be transferred back to SUTD by submitting an official transcript from the host university to our Registrar's Office for evaluation. The credits will be assessed based on equivalency to SUTD courses and will be reflected on the student's academic record accordingly. It is important for students to plan their exchange program in advance and consult with their academic advisors to ensure a smooth credit transfer process.
#
# [66] Does SUTD offer support for visa applications and other logistical arrangements for exchange programs?
# → Yes, SUTD provides support for visa applications and other logistical arrangements for exchange programs. Our International Relations Office assists students with the necessary documentation and guidance throughout the process. We aim to ensure a smooth and hassle-free experience for students participating in exchange programs.
#
# [67] What types of academic programs or specializations are available through SUTD's global exchange partners?
# → SUTD's global exchange partners offer various academic programs and specializations in areas such as design, engineering, technology, and business. Students have the opportunity to explore a wide range of courses, gaining valuable international perspectives and experiences. Each partner university has its own unique strengths and expertise, providing students with diverse learning opportunities to enhance their education at SUTD.
#
# [68] Are there opportunities for internships or research projects in conjunction with a global exchange program?
# → Yes, SUTD offers opportunities for internships and research projects in conjunction with our global exchange programs. Students have the chance to work on real-world projects with industry partners and top universities around the world. These experiences help students develop valuable skills and gain international exposure.
#
# [69] Can you connect me with current SUTD students who have participated in a global exchange program to hear about their experiences?
# → Certainly! We encourage you to reach out to our Student Affairs Office or the Global Relations Office for assistance in connecting with current SUTD students who have participated in global exchange programs. They will be able to provide you with valuable insights and experiences to help you better understand the opportunities available for students at SUTD.
#
# [70] What research opportunities are available for undergraduates at SUTD, specifically within my intended major?
# → At SUTD, undergraduates have various research opportunities within their majors. Students can participate in research projects under faculty supervision, work on industry-sponsored projects, or pursue independent research through special programs. The university also encourages students to engage in cross-disciplinary research to broaden their perspectives. Additionally, there are research internships and exchange programs available for students to gain experience and exposure to different research settings. Contact the respective faculty in your intended major for more information on specific research opportunities available.
#
# [71] How early can undergraduates get involved in research at SUTD?
# → Undergraduates at SUTD can get involved in research as early as their freshman year through various research programs, initiatives, and opportunities offered by the university. These include research internships, project-based learning, and collaboration with faculty members on cutting-edge research projects. Students are encouraged to explore their interests and seek out research opportunities to enhance their learning experience.
#
# [72] Are there summer research programs or internships specifically for SUTD undergraduates?
# → Yes, SUTD offers various summer research programs and internships for our undergraduates. These opportunities allow students to gain valuable research experience, work on real-world projects, and collaborate with industry partners. Students can apply for these programs through the university's dedicated platforms and career services.
#
# [73] Can undergraduates collaborate with faculty on their ongoing research projects?
# → Yes, undergraduates at SUTD have the opportunity to collaborate with faculty on their ongoing research projects. This hands-on experience allows students to apply classroom knowledge to real-world challenges and gain valuable research skills. Collaborating with faculty members also provides students with mentorship and guidance in their academic pursuits.
#
# [74] Does SUTD offer funding or scholarships to support undergraduate research?
# → Yes, SUTD provides various funding opportunities and scholarships to support undergraduate research. Students can apply for research grants, participate in research programs, and seek mentorship from faculty members. Additionally, there are scholarships available for outstanding students to support their research endeavors. We encourage students to explore these opportunities and engage in research activities to enhance their learning experience at SUTD.
#
# [75] What is the application process for undergraduate research positions at SUTD?
# → To apply for undergraduate research positions at SUTD, students can explore opportunities through faculty research projects, research centers, or programs like the SUTD-MIT International Design Center. Interested students should reach out directly to faculty members or research centers to express their interest, discuss available projects, and submit any required application materials. It is also beneficial to have a strong academic background and relevant skills for the specific research area of interest.
#
# [76] Are there opportunities to present research findings at conferences or publish in journals as an undergraduate?
# → Yes, at SUTD, undergraduate students have opportunities to present their research findings at conferences and publish in journals. Students are encouraged to engage in research projects and collaborate with faculty members on cutting-edge research. SUTD also supports students in their academic endeavors by providing guidance and resources to help them showcase their work on a wider platform.
#
# [77] How does undergraduate research experience at SUTD benefit career prospects or graduate school applications?
# → Undergraduate research experience at SUTD provides students with hands-on opportunities to apply theoretical knowledge in real-world scenarios, enhancing problem-solving and critical thinking skills. This experience demonstrates a student's ability to conduct independent research, collaborate with peers, and communicate findings effectively. These skills are highly valued by both employers and graduate school admissions committees, making SUTD graduates well-equipped for successful careers or further academic pursuits.
#
# [78] Can research be incorporated into the undergraduate curriculum, such as through UROP or thesis projects?
# → Yes, research is an integral part of the undergraduate curriculum at SUTD. Students have the opportunity to engage in research through programs like the Undergraduate Research Opportunities Program (UROP) and thesis projects. These experiences allow students to work closely with faculty members on cutting-edge research projects and gain valuable skills in their chosen field of study.
#
# [79] What are the mentorship opportunities available for undergraduates engaging in research at SUTD?
# → At SUTD, undergraduates engaging in research have the opportunity to work closely with faculty mentors who provide guidance and support throughout their research projects. Our faculty members are experts in their fields and are committed to helping students develop their research skills. Additionally, students can also seek mentorship from graduate students and industry partners involved in research projects, allowing for a well-rounded learning experience.
#
# [80] What types of scholarships are available at SUTD, and what are their specific eligibility criteria?
# → At SUTD, we offer various scholarships to support our students, such as the SUTD Global Excellence Scholarship, SUTD Scholarship, and SUTD Study Awards. Eligibility criteria vary for each scholarship but generally consider academic achievements, leadership potential, and financial needs. We encourage all prospective students to visit our website for detailed information on specific scholarships and their eligibility requirements.
#
# [81] How competitive are SUTD scholarships, and what is the average award amount?
# → SUTD scholarships are highly competitive, with a limited number awarded each year. The average award amount varies depending on the scholarship type and recipient's qualifications. Students are encouraged to demonstrate exceptional academic performance, leadership qualities, and passion for innovation to increase their chances of receiving a scholarship. It is recommended to check our website for updated information on scholarship opportunities and criteria.
#
# [82] Does SUTD offer scholarships specifically for international students?
# → Yes, SUTD offers scholarships for both local and international students. These scholarships are awarded based on academic merit, extracurricular achievements, leadership potential, and financial need. International students are encouraged to apply for these scholarships to support their studies at SUTD.
#
# [83] Are there any scholarships tied to specific academic programs or disciplines at SUTD?
# ...
#
# [175] What support is available for students struggling academically, such as tutoring or study groups?
# → SUTD offers various academic support services for students, including tutoring, study groups, and academic advising. The Academic Resource Center provides resources and assistance to help students excel in their studies. Additionally, students can seek guidance from professors, teaching assistants, and peer mentors for extra support. Our goal is to ensure that all students have the necessary resources to succeed academically.
#
# [176] Does SUTD provide resources for students with learning disabilities or other specific learning needs?
# → Yes, SUTD is committed to providing support and accommodations for students with learning disabilities or specific learning needs. Our Student Care team works closely with students to understand their individual requirements and provide appropriate resources such as extra time for exams, assistive technologies, and academic support services. We strive to create an inclusive learning environment where all students can thrive and succeed.
#
# [177] Are there support services specifically for international students, such as visa assistance or cultural adjustment programs?
# → Yes, SUTD provides support services for international students, including visa assistance, cultural adjustment programs, and access to international student advisors. We understand the unique challenges international students may face and are committed to helping them navigate through their academic journey at SUTD.
#
# [178] How does SUTD promote a sense of community and belonging among its students?
# → SUTD promotes a strong sense of community and belonging through various student clubs, activities, and events that foster collaboration and friendships. Our small student-to-faculty ratio encourages close interactions, and our unique pedagogy emphasizes teamwork and project-based learning, creating a supportive environment. Additionally, our campus design encourages social interactions and a vibrant student life.
#
# [179] What are the procedures for accessing student support services at SUTD, and who can I contact for more information?
# → To access student support services at SUTD, students can reach out to the Student Services team. They provide assistance with academic, personal, and career-related concerns. Students can contact the Student Services team via email at studentservices@sutd.edu.sg or visit their office on campus. Additionally, information on support services can be found on the SUTD website or through the student handbook.
#
# [180] How active is the SUTD alumni network in supporting recent graduates in finding job opportunities?
# → The SUTD alumni network is highly active and plays a significant role in supporting recent graduates in finding job opportunities. Alumni often provide mentorship, networking opportunities, and referrals to job openings. SUTD also organizes career fairs, networking events, and workshops to facilitate connections between students and alumni for career advancement.
#
# [181] Does SUTD facilitate mentorship programs connecting current students with alumni working in specific industries I'm interested in (e.g., [mention specific industry])?
# → Yes, at SUTD, we offer mentorship programs that connect current students with alumni working in various industries, including [specific industry]. These programs provide valuable insights, guidance, and networking opportunities to help students gain a better understanding of their chosen field and make informed career decisions.
#
# [182] Are there opportunities to network with alumni beyond formal mentorship programs, such as alumni events or online platforms?
# → Yes, at SUTD, we provide various opportunities for students to network with alumni beyond formal mentorship programs. We organize alumni events, networking sessions, and industry talks where students can interact with and learn from our alumni. Additionally, we have an online platform where students can connect with alumni for mentorship, advice, and career opportunities. These initiatives help our students build a strong network and gain valuable insights from experienced professionals in their field of interest.
#
# [183] What kind of support does SUTD provide to alumni who are interested in mentoring current students?
# → SUTD actively supports alumni who are interested in mentoring current students by facilitating networking events, workshops, and mentorship programs. The university also provides resources and platforms for alumni to connect with students, share their experiences, and offer guidance in various fields. Alumni are encouraged to engage with students through career fairs, industry talks, and mentorship initiatives to foster a strong SUTD community and promote professional development opportunities.
#
# [184] Can you share success stories or testimonials from students who have benefited from the alumni network and mentorship program?
# → Our alumni network and mentorship program have been instrumental in guiding students towards successful career paths. Many of our alumni have returned to mentor current students, providing valuable insights and networking opportunities. Students have secured internships, job placements, and even entrepreneurship opportunities through these connections. The mentorship program has also helped students navigate academic challenges and personal development. These success stories showcase the strength and impact of our alumni network and mentorship program in shaping students' futures.
#
# [185] How does SUTD leverage its relatively young alumni network to provide unique opportunities for current students?
# → SUTD leverages its young alumni network by organizing networking events, alumni talks, and mentorship programs for current students. These opportunities allow students to gain insights into various industries, receive career guidance, and build valuable connections for internships and job placements. Additionally, alumni often contribute to curriculum development, provide project collaborations, and offer real-world experiences to enrich the educational experience at SUTD.
#
# [186] What is the typical engagement rate of alumni in mentorship and networking activities?
# → Our alumni are highly engaged in mentorship and networking activities, with a typical engagement rate of over 70%. They actively participate in various programs and events to support current students and build connections within the SUTD community. Alumni play a crucial role in providing guidance, advice, and opportunities for our students' personal and professional development.
#
# [187] Does SUTD have any international alumni chapters or networks that can support students interested in working abroad?
# → Yes, SUTD has an active international alumni network that spans across various countries. Our alumni chapters provide valuable support and resources for students interested in working abroad, including networking opportunities, job placements, and career advice. These connections can be beneficial for students looking to explore global career opportunities and expand their professional networks.
#
# [188] How does the alumni network contribute to the development of SUTD's curriculum and industry partnerships?
# → SUTD's alumni network plays a vital role in shaping the curriculum through feedback, industry insights, and real-world experiences. Alumni provide valuable input on current industry trends and needs, which helps ensure that our programs remain relevant and up-to-date. Additionally, alumni often serve as industry partners, collaborators, and mentors, fostering strong connections between academia and industry. Their continued involvement strengthens SUTD's industry partnerships, leading to more opportunities for internships, research projects, and job placements for our students.
#
# [189] Are there specific resources or platforms available for students to connect with alumni based on shared interests or career goals?
# → Yes, at SUTD, we have a dedicated Career Development Office that organizes various networking events, workshops, and mentorship programs where students can connect with alumni based on shared interests or career goals. Additionally, our alumni network actively participates in industry panels, career fairs, and networking sessions to provide guidance and support to current students.
#
# [190] What specific digital manufacturing technologies, like 3D printing, robotics, or AI-driven design, are emphasized in SUTD's curriculum?
# → SUTD's curriculum emphasizes digital manufacturing technologies such as 3D printing, robotics, and AI-driven design. Students learn to leverage these technologies through hands-on projects and courses like Advanced Manufacturing, Robotics, and Artificial Intelligence. These skills are crucial for preparing students to tackle real-world challenges and innovate in various industries.
#
# [191] How does SUTD's design-centric approach integrate with the digital manufacturing focus in this program?
# → SUTD's design-centric approach is complemented by the digital manufacturing focus in our program through hands-on projects that merge creativity with technological innovation. Students apply design thinking principles to develop products using advanced digital tools like 3D printing and CNC machining. This integration ensures that students not only conceptualize innovative solutions but also have the skills to bring their ideas to life efficiently and effectively in real-world applications.
#
# [192] What opportunities are there for hands-on experience with industry-standard digital manufacturing equipment and software?
# → At SUTD, students have access to our well-equipped Fabrication Lab, featuring industry-standard digital manufacturing equipment such as 3D printers, laser cutters, and CNC machines. Our curriculum integrates hands-on projects, giving students practical experience in using these tools. Additionally, students can participate in industry collaborations, internships, and design competitions to further develop their skills in digital manufacturing.
#
# [193] Can you provide examples of real-world projects or case studies students work on related to digital manufacturing and design?
# → SUTD students have the opportunity to work on various real-world projects related to digital manufacturing and design. Some examples include designing and prototyping smart devices, creating interactive installations for public spaces, and developing innovative solutions for industrial automation. Students also collaborate with industry partners on projects such as optimizing manufacturing processes, implementing IoT technologies in production lines, and designing sustainable products using digital fabrication techniques. These projects provide students with hands-on experience and valuable skills in digital manufacturing and design.
#
# [194] What are the career prospects for graduates specializing in digital manufacturing and design from SUTD?
# → Graduates specializing in digital manufacturing and design from SUTD have promising career prospects in various industries such as aerospace, automotive, robotics, and more. They are equipped with skills in advanced manufacturing technologies, design thinking, and digital tools, making them highly sought after by employers for roles in product development, manufacturing engineering, research and development, and innovation management. The interdisciplinary nature of the program also prepares them for leadership positions in the rapidly evolving industry of digital manufacturing.
#
# [195] How does SUTD's focus on digital manufacturing prepare students for the future of Industry 4.0?
# → SUTD's focus on digital manufacturing equips students with hands-on experience in cutting-edge technologies like 3D printing, robotics, and automation. This prepares them for the Industry 4.0 landscape by developing skills in advanced manufacturing processes, data analytics, and smart technologies. Students learn to innovate and create solutions that are essential in the rapidly evolving digital economy, ensuring they are well-prepared for the future workforce.
#
# [196] Are there opportunities for internships or research collaborations with companies in the digital manufacturing sector?
# → Yes, at SUTD we offer opportunities for internships and research collaborations with companies in the digital manufacturing sector. Our strong industry partnerships and focus on real-world applications provide students with valuable hands-on experience and networking opportunities in this field. Students can gain practical experience and work on cutting-edge projects with leading companies in the industry, enhancing their skills and preparing them for future careers in digital manufacturing.
#
# [197] What specific design software and programming languages are taught within the digital manufacturing and design focus?
# → In the digital manufacturing and design focus at SUTD, students are exposed to design software such as SolidWorks, AutoCAD, and Rhino, and programming languages like Python, MATLAB, and C++. These tools are essential for students to develop skills in computer-aided design, simulation, and programming to effectively design, analyze, and manufacture products in a digital environment.
#
# [198] How does SUTD's interdisciplinary curriculum contribute to a well-rounded understanding of digital manufacturing, including aspects like data analytics and cybersecurity?
# → SUTD's interdisciplinary curriculum integrates various fields such as engineering, design, and humanities to provide a holistic understanding of digital manufacturing. Students learn data analytics to optimize processes and cybersecurity to protect systems. By exploring these diverse areas, students gain a comprehensive perspective on digital manufacturing, preparing them for real-world challenges in Industry 4.0.
#
# [199] What are the pathways for further specialization or research within digital manufacturing and design after completing an undergraduate degree at SUTD?
# → After completing an undergraduate degree at SUTD in the field of digital manufacturing and design, students can pursue further specialization through our Master's or PhD programs in Advanced Manufacturing Technologies or Design and Digital Fabrication. These programs offer opportunities for advanced research and hands-on experience in cutting-edge technologies, preparing students for careers in academia, industry, or research institutions. Additional options include joining research centers, collaborating on industry projects, or participating in internships to deepen expertise in the field.
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Uploading the dataset shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Creating parquet from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# Uploading the dataset shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Creating parquet from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# README.md:   0%|          | 0.00/482 [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/datasets/DrakeLLLLLLL/sutd_qa_dataset/commit/7dedeb9197fd33cbf14ea80fae070a200d79a7bd', commit_message='Upload dataset', commit_description='', oid='7dedeb9197fd33cbf14ea80fae070a200d79a7bd', pr_url=None, repo_url=RepoUrl('https://huggingface.co/datasets/DrakeLLLLLLL/sutd_qa_dataset', endpoint='https://huggingface.co', repo_type='dataset', repo_id='DrakeLLLLLLL/sutd_qa_dataset'), pr_revision=None, pr_num=None)

# %%
# test the chain

# Define the generation function
def generate_answer(question):
    prompt = f"You are a helpful assistant for SUTD admissions. Answer the following question in less than 100 words:\n{question}"

    try:
        response = client.chat.completions.create(
            model="gpt-3.5-turbo",
            messages=[
                {"role": "system", "content": "You are an expert in SUTD university matters."},
                {"role": "user", "content": prompt}
            ],
            temperature=0.7
        )
        answer_text = response.choices[0].message.content.strip()
        return {"answer": answer_text}

    except Exception as e:
        print(f"Error: {e}")
        return {"answer": "Unable to generate an answer at this time."}

question = "When was SUTD founded?"

# Now run the answer generation chain
response = generate_answer(question)
print("\nModel Response:")
print(response["answer"])
# Out:
# Model Response:
# SUTD, also known as the Singapore University of Technology and Design, was founded in collaboration with the Massachusetts Institute of Technology (MIT) on 30 October 2009.

# %% [markdown]
# # Finetune Llama 3.2 1B model
#
# Now use your SUTD QA dataset training data set to finetune a smaller Llama 3.2 1B LLM using parameter-efficient finetuning (PEFT).
# We recommend the unsloth library but you are free to choose other frameworks. You can decide the parameters for the finetuning.
# Push your finetuned model to Huggingface.
#
# Then we will compare the finetuned and non-finetuned LLMs with and without RAG to see if we were able to improve the SUTD chatbot answer quality.

# %%
import torch
print(torch.cuda.is_available())  # Should return True
# Out:
# True

# %%
# log in to hugging face repo
login("")

# %%
print(f"Available GPU memory: {torch.cuda.get_device_properties(0).total_memory/1e9:.2f}GB")
# Out:
# Available GPU memory: 23.80GB

# %%
torch.cuda.empty_cache() #offload gpu before running

# %%
# Install dependencies
# !pip install --no-cache-dir bitsandbytes
# !pip install -U peft transformers datasets accelerate

# Import required libraries
from datasets import load_dataset
from transformers import (
    AutoTokenizer,
    AutoModelForCausalLM,
    TrainingArguments,
    Trainer,
    DataCollatorForLanguageModeling,
    BitsAndBytesConfig,
)
from peft import get_peft_model, LoraConfig
import torch

# HF Hub details
model_name = "meta-llama/Llama-3.2-1B"
hf_model_id = ""
hf_token = ""  # 

# Step 1: Load dataset
dataset = load_dataset("dataset") ##import dataset
train_data = dataset["train"]

# Step 2: Tokenizer
tokenizer = AutoTokenizer.from_pretrained(model_name)
tokenizer.pad_token = tokenizer.eos_token

# Step 3: BitsAndBytesConfig for quantized loading
bnb_config = BitsAndBytesConfig(
    load_in_8bit=True,
    llm_int8_threshold=6.0,
    llm_int8_has_fp16_weight=True
)

# Step 4: Load quantized model
model = AutoModelForCausalLM.from_pretrained(
    model_name,
    torch_dtype=torch.float16,
    device_map="auto"
)

# Step 5: Apply LoRA config
peft_config = LoraConfig(
    r=8,
    lora_alpha=16,
    target_modules=["q_proj", "v_proj"],
    lora_dropout=0.05,
    bias="none",
    task_type="CAUSAL_LM",
)
model = get_peft_model(model, peft_config)

# Step 6: Tokenize dataset
def format_and_tokenize(example):
    prompt = f"### Question: {example['question']}\n### Answer: {example['answer']}"
    tokenized = tokenizer(
        prompt,
        truncation=True,
        padding="max_length",
        max_length=512,
    )
    tokenized["labels"] = tokenized["input_ids"].copy()
    return tokenized

tokenized_dataset = train_data.map(format_and_tokenize)

# Step 7: Training arguments
training_args = TrainingArguments(
    per_device_train_batch_size=4,
    gradient_accumulation_steps=2,
    warmup_steps=10,
    num_train_epochs=3,
    learning_rate=2e-4,
    fp16=True,
    logging_steps=10,
    output_dir="./finetuned-llama3-sutd",
    save_strategy="epoch",
    push_to_hub=True,
    hub_model_id=hf_model_id,
    hub_token=hf_token,
)

# Step 8: Train using Hugging Face Trainer
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_dataset,
    tokenizer=tokenizer,
    data_collator=DataCollatorForLanguageModeling(tokenizer, mlm=False),
)

# Step 9: Launch training + Push to Hub
trainer.train()
trainer.push_to_hub()
# Out:
# Requirement already satisfied: bitsandbytes in /usr/local/lib/python3.11/dist-packages (0.45.5)
# Requirement already satisfied: torch<3,>=2.0 in /usr/local/lib/python3.11/dist-packages (from bitsandbytes) (2.6.0+cu124)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from bitsandbytes) (2.0.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (4.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (2024.12.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch<3,>=2.0->bitsandbytes) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch<3,>=2.0->bitsandbytes) (3.0.2)
# Requirement already satisfied: peft in /usr/local/lib/python3.11/dist-packages (0.15.2)
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (4.51.3)
# Requirement already satisfied: datasets in /usr/local/lib/python3.11/dist-packages (3.5.0)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.11/dist-packages (1.6.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from peft) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from peft) (24.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from peft) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from peft) (6.0.2)
# Requirement already satisfied: torch>=1.13.0 in /usr/local/lib/python3.11/dist-packages (from peft) (2.6.0+cu124)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from peft) (4.67.1)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.11/dist-packages (from peft) (0.5.3)
# Requirement already satisfied: huggingface_hub>=0.25.0 in /usr/local/lib/python3.11/dist-packages (from peft) (0.30.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers) (3.18.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.21.1)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.11/dist-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2024.12.0,>=2023.1.0 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]<=2024.12.0,>=2023.1.0->datasets) (2024.12.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from datasets) (3.11.15)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (6.4.3)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.19.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub>=0.25.0->peft) (4.13.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2025.1.31)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.13.0->peft) (1.3.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.13.0->peft) (3.0.2)
# Map:   0%|          | 0/160 [00:00<?, ? examples/s]
# <ipython-input-7-550f83dd731b>:87: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer.__init__`. Use `processing_class` instead.
#   trainer = Trainer(
# No label_names provided for model class `PeftModelForCausalLM`. Since `PeftModel` hides base models input arguments, if label_names is not given, label_names can't be set automatically within `Trainer`. Note that empty label_names list will be used instead.
# wandb: WARNING The `run_name` is currently set to the same value as `TrainingArguments.output_dir`. If this was not intended, please specify a different run name by setting the `TrainingArguments.run_name` parameter.
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter:
#  ··········
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: yu2_liu (yu2_liu-sutd) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.19.9
# Run data is saved locally in <code>/content/wandb/run-20250423_151500-vkbt91i6</code>
# Syncing run <strong><a href='https://wandb.ai/yu2_liu-sutd/huggingface/runs/vkbt91i6' target="_blank">./finetuned-llama3-sutd</a></strong> to <a href='https://wandb.ai/yu2_liu-sutd/huggingface' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/yu2_liu-sutd/huggingface' target="_blank">https://wandb.ai/yu2_liu-sutd/huggingface</a>
#  View run at <a href='https://wandb.ai/yu2_liu-sutd/huggingface/runs/vkbt91i6' target="_blank">https://wandb.ai/yu2_liu-sutd/huggingface/runs/vkbt91i6</a>
#     <div>
#
#       <progress value='60' max='60' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [60/60 00:43, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>10</td>
#       <td>1.936200</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>1.699900</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>1.478100</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>1.406500</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>1.351000</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>1.299300</td>
#     </tr>
#   </tbody>
# </table><p>
# CommitInfo(commit_url='https://huggingface.co/ayupermhm/llama-3.2-1B-sutdqa/commit/385099c910ec0a91cf05639827ea7adf47c985cc', commit_message='End of training', commit_description='', oid='385099c910ec0a91cf05639827ea7adf47c985cc', pr_url=None, repo_url=RepoUrl('https://huggingface.co/ayupermhm/llama-3.2-1B-sutdqa', endpoint='https://huggingface.co', repo_type='model', repo_id='ayupermhm/llama-3.2-1B-sutdqa'), pr_revision=None, pr_num=None)

# %%
# Train and push to Hub
trainer.train()
trainer.push_to_hub()
tokenizer.push_to_hub("ayupermhm/llama-3.2-1B-sutdqa")
# Out:
#     <div>
#
#       <progress value='60' max='60' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [60/60 00:44, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>10</td>
#       <td>1.292800</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>1.270800</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>1.192900</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>1.206500</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>1.168000</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>1.133300</td>
#     </tr>
#   </tbody>
# </table><p>
# No files have been modified since last commit. Skipping to prevent empty commit.
# WARNING:huggingface_hub.hf_api:No files have been modified since last commit. Skipping to prevent empty commit.
# README.md:   0%|          | 0.00/1.32k [00:00<?, ?B/s]
# No files have been modified since last commit. Skipping to prevent empty commit.
# WARNING:huggingface_hub.hf_api:No files have been modified since last commit. Skipping to prevent empty commit.
# CommitInfo(commit_url='https://huggingface.co/ayupermhm/llama-3.2-1B-sutdqa/commit/577d52dd9f9b5c11c109725357429f35d7307a7b', commit_message='Upload tokenizer', commit_description='', oid='577d52dd9f9b5c11c109725357429f35d7307a7b', pr_url=None, repo_url=RepoUrl('https://huggingface.co/ayupermhm/llama-3.2-1B-sutdqa', endpoint='https://huggingface.co', repo_type='model', repo_id='ayupermhm/llama-3.2-1B-sutdqa'), pr_revision=None, pr_num=None)

# %%
# QUESTION: Load a non-finetuned Llama 3.2 1B model and your finetuned SUTD QA Llama 3.2 1B model
# Ask it a simple test question (e.g. "What is special about SUTD?") to check that both models can generated answers

#--- ADD YOUR SOLUTION HERE (10 points)---

device = "cuda" if torch.cuda.is_available() else "cpu"

# Load base model
base_model_id = "meta-llama/Llama-3.2-1B"
base_tokenizer = AutoTokenizer.from_pretrained(base_model_id)
base_model = AutoModelForCausalLM.from_pretrained(
    base_model_id,
    torch_dtype=torch.float16,
    device_map="auto",
) # Explicitly move to device

# Load finetuned model
finetuned_model_id = "ayupermhm/llama-3.2-1B-sutdqa"
finetuned_tokenizer = AutoTokenizer.from_pretrained(finetuned_model_id)

# Load PEFT model correctly
peft_config = PeftConfig.from_pretrained(finetuned_model_id)
base_model_for_peft = AutoModelForCausalLM.from_pretrained(
    peft_config.base_model_name_or_path,
    torch_dtype=torch.float16,
    device_map="auto",
).to(device)  # Explicitly move to device

finetuned_model = PeftModel.from_pretrained(
    base_model_for_peft,
    finetuned_model_id,
    torch_dtype=torch.float16,
).to(device)  # Explicitly move to device

# Generation functions with device handling
def generate_base(prompt):
    inputs = base_tokenizer(prompt, return_tensors="pt").to(device)  # Move inputs to device
    with torch.inference_mode():
        outputs = base_model.generate(
            **inputs,
            max_new_tokens=256,
            do_sample=True,
            temperature=0.7,
            top_p=0.9,
            repetition_penalty=1.2,
        )
    return base_tokenizer.decode(outputs[0], skip_special_tokens=True)

def generate_finetuned(prompt):
    inputs = finetuned_tokenizer(prompt, return_tensors="pt").to(device)  # Move inputs to device
    with torch.inference_mode():
        outputs = finetuned_model.generate(
            **inputs,
            max_new_tokens=256,
            do_sample=True,
            temperature=0.7,
            top_p=0.9,
            repetition_penalty=1.2,
        )
    return finetuned_tokenizer.decode(outputs[0], skip_special_tokens=True)
# Out:
# tokenizer_config.json:   0%|          | 0.00/50.6k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.2M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/335 [00:00<?, ?B/s]
# adapter_config.json:   0%|          | 0.00/778 [00:00<?, ?B/s]
# adapter_model.safetensors:   0%|          | 0.00/3.42M [00:00<?, ?B/s]

# %%
# try out the llms

query = "What is special about SUTD?"

print("Question:", query)
response_base = generate_base(query)
print("Answer base:", response_base)

print("---------")

# Generate response from finetuned model
response_finetune = generate_finetuned(query)
print("Answer finetune:", response_finetune)
# Out:
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Question: What is special about SUTD?
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Answer base: What is special about SUTD? It’s an idea of a new school that puts innovation, creativity and design at the heart of its education. This year marks our 10th anniversary as we continue to develop this vision.
# In fact, in some ways you could say it was born out of necessity — or maybe even destiny! As Singapore grows into one of Asia's most dynamic economies, there are increasing demands for talent who have both technical expertise and creative flair.
# With growing globalisation and technological advances shaping how businesses operate across industries today, companies need employees with these two skills sets more than ever before!
# As such, many universities throughout Asia now offer courses which combine theoretical knowledge from engineering disciplines like civil & structural engineering; mechanical engineering etc., alongside practical application through hands-on projects involving fabrication techniques such as metal forming processes (e.g casting), machining operations using CNC machine tools plus other allied technologies including industrial robotics applications within manufacturing industry contexts where advanced production systems exist already deployed commercially e.g automotive assembly lines).
# SUSTAINABLE DEVELOPMENT AND ECONOMIC GROWTH
# To be sustainable development means achieving economic growth while preserving natural resources without compromising on social well-being - it requires us all working together towards shared goals around sustainability principles such as protecting biodiversity conservation areas such as mangroves forests islands coastal zones inland wetlands
# ---------
# Answer finetune: What is special about SUTD? How does it compare to other universities in Singapore?
# SUTD has a unique approach that sets us apart from traditional higher education institutions. We are known for our emphasis on creativity, innovation and design thinking, which aligns well with the needs of industry. Additionally, we offer an interdisciplinary curriculum that allows students to explore various fields simultaneously, providing them with broad-based skills and knowledge. Our small classes allow students to work closely with faculty members and peers, fostering collaboration and problem-solving abilities essential in today's rapidly changing world.
# Is there any specific program at SUTD designed specifically for entrepreneurs or startups looking to launch their own ventures within campus environments?
# Yes, SUTD offers several specialized programs tailored towards entrepreneurship and startup ecosystems. These include the Entrepreneurship & Innovation (E&I) Program, Startup Design Thinking Lab, as well as hands-on workshops focused on nurturing entrepreneurial spirit among students through real-world projects aligned with current market demands. Our collaborative environment fosters innovative ideas leading up to successful venture launches on-campus. Students benefit greatly by engaging directly with industry partners and mentors who support their growth journey throughout these initiatives.

# %% [markdown]
# # Integrate and evaluate
#
# Now integrate both the non-finetuned Llama 3.2 1B model and your finetuned model into your SUTD chatbot RAG system.
# Generate responses to the 20 questions you have collected in assignment 3 using these 4 appraoches
# 1. non-finetuned Llama 3.2 1B model without RAG
# 2. finetuned Llama 3.2 1B SUTD QA model without RAG
# 3. non-finetuned Llama 3.2 1B model with RAG
# 4. finetuned Llama 3.2 1B SUTD QA model with RAG
#
# Compare the responses and decide what system produces the most accurate and high quality responses

# %%
# !pip install faiss-cpu

# Import
import os
import json
import torch
from dotenv import load_dotenv
from tqdm import tqdm
from langchain.document_loaders import PyPDFLoader

# Langchain & data loaders
from langchain.document_loaders import UnstructuredURLLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter

# Embedding + vector store
from langchain.embeddings import HuggingFaceEmbeddings
from langchain.vectorstores import FAISS

# Model
from transformers import AutoTokenizer, AutoModelForCausalLM, pipeline

# LangChain for RAG
from langchain.chains import RetrievalQA
from langchain.llms import HuggingFacePipeline

from langchain.prompts import PromptTemplate
from langchain import hub
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnablePassthrough
import re

from IPython.display import HTML, display
# Out:
# Collecting faiss-cpu
#   Downloading faiss_cpu-1.10.0-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (4.4 kB)
# Requirement already satisfied: numpy<3.0,>=1.25.0 in /usr/local/lib/python3.11/dist-packages (from faiss-cpu) (2.0.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from faiss-cpu) (24.2)
# Downloading faiss_cpu-1.10.0-cp311-cp311-manylinux_2_28_x86_64.whl (30.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.7/30.7 MB 76.6 MB/s eta 0:00:00
# Installing collected packages: faiss-cpu
# Successfully installed faiss-cpu-1.10.0

# %%
embeddings = HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")
vectorstore = FAISS.load_local("sutd_faiss_index", embeddings, allow_dangerous_deserialization=True)
print("Success! Vectorstore loaded 🎉")
# Out:
# Success! Vectorstore loaded 🎉

# %%
# QUESTION: Re-create the RAG chatbot system you have created in assignment 3 but with the Llama 3.2 1B (non-tuned and finetuned) models

#--- ADD YOUR SOLUTION HERE (40 points)---
# Load questions from assignment 3
test_questions = ["What are the admissions deadlines for SUTD?",
             "Is there financial aid available?",
             "What is the minimum score for the Mother Tongue Language?",
             "Do I require reference letters?",
             "Can polytechnic diploma students apply?",
             "Do I need SAT score?",
             "How many PhD students does SUTD have?",
             "How much are the tuition fees for Singaporeans?",
             "How much are the tuition fees for international students?",
             "Is there a minimum CAP?"
             ]
test_questions.extend([ "What is the difference between CSD in SUTD and Computer Science major in nus?",
                  "What is the teaching style like in SUTD?",
                  "What are the possible career path for ESD pillar?",
                  "How heavy are the project workload like in SUTD?",
                  "How does the employment rates of SUTD compare to other universities like NUS and NTU?",
                  "Who can I approach if I have more questions about SUTD?",
                  "What is the difference between CSD and DAI?",
                  "Can you tell me about the admission process?",
                  "How can I prepare for the admission process?",
                  "What is the meaning of pillar?"
])

# Check CUDA availability
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using device: {device}")

def load_vectorstore():
    """Load or create vector store for our documents"""
    if os.path.exists("sutd_faiss_index"):
        embedding_model = HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")
        vectorstore = vectorstore = FAISS.load_local("sutd_faiss_index", embedding_model, allow_dangerous_deserialization=True)
        print("Loaded existing FAISS index")
    else:
        print("Loading documents from scratch...")
        raise FileNotFoundError("Please run document loading from assignment 3 first")

    return vectorstore

# 2. Set up retriever
vectorstore = load_vectorstore()
retriever = vectorstore.as_retriever(search_kwargs={"k": 7})

# 3. Define generation functions for all 4 approaches
def format_docs(docs):
    """Format retrieved documents into context string"""
    return "\n\n".join(doc.page_content for doc in docs)

# For non-finetuned model without RAG
def generate_base_no_rag(question):
    """Generate response using base model without RAG"""
    prompt = f"You are a helpful assistant for SUTD university answering questions from prospective students. Answer the following question in a helpful and friendly way:\n\nQuestion: {question}\n\nAnswer:"
    inputs = base_tokenizer(prompt, return_tensors="pt", truncation=True).to(device)
    outputs = base_model.generate(
        **inputs,
        max_new_tokens=256,
        do_sample=True,
        temperature=0.7,
        top_p=0.9,
        repetition_penalty=1.2,
    )
    response = base_tokenizer.decode(outputs[0], skip_special_tokens=True)
    # Extract just the answer part
    try:
        answer = response.split("Answer:")[1].strip()
    except:
        answer = response
    return answer

# For finetuned model without RAG
def generate_finetuned_no_rag(question):
    """Generate response using finetuned model without RAG"""
    prompt =  f"You are a helpful assistant for SUTD university answering questions from prospective students. Answer the following question in a helpful and friendly way:\n\nQuestion: {question}\n\nAnswer:"
    inputs = finetuned_tokenizer(prompt, return_tensors="pt", truncation=True).to(device)
    outputs = finetuned_model.generate(
        **inputs,
        max_new_tokens=256,
        do_sample=True,
        temperature=0.7,
        top_p=0.9,
        repetition_penalty=1.2,
    )
    response = finetuned_tokenizer.decode(outputs[0], skip_special_tokens=True)
    # Extract just the answer part
    try:
        answer = response.split("Answer:")[1].strip()
    except:
        answer = response
    return answer

# For base model with RAG
def generate_base_with_rag(question):
    """Generate response using base model with RAG"""
    docs = retriever.get_relevant_documents(question)
    context = format_docs(docs)

    prompt = f"""You are a helpful assistant for SUTD university answering questions from prospective students.
Use the following context information to answer the question. If you don't know the answer based on the provided context, say that you don't have enough information.

Context:
{context}

Question: {question}

Answer:"""

    inputs = base_tokenizer(prompt, return_tensors="pt", truncation=True).to(device)
    outputs = base_model.generate(
        **inputs,
        max_new_tokens=256,
        do_sample=True,
        temperature=0.7,
        top_p=0.9,
        repetition_penalty=1.2,
    )
    response = base_tokenizer.decode(outputs[0], skip_special_tokens=True)
    # Extract just the answer part
    try:
        answer = response.split("Answer:")[1].strip()
    except:
        answer = response
    return answer, docs

# For finetuned model with RAG
def generate_finetuned_with_rag(question):
    """Generate response using finetuned model with RAG"""
    docs = retriever.get_relevant_documents(question)
    context = format_docs(docs)

    prompt = f"""You are a helpful assistant for SUTD university answering questions from prospective students.
Use the following context information to answer the question. If you don't know the answer based on the provided context, say that you don't have enough information.

Context:
{context}

Question: {question}

Answer:"""

    inputs = finetuned_tokenizer(prompt, return_tensors="pt", truncation=True).to(device)
    outputs = finetuned_model.generate(
        **inputs,
        max_new_tokens=256,
        do_sample=True,
        temperature=0.7,
        top_p=0.9,
        repetition_penalty=1.2,
    )
    response = finetuned_tokenizer.decode(outputs[0], skip_special_tokens=True)
    # Extract just the answer part
    try:
        answer = response.split("Answer:")[1].strip()
    except:
        answer = response
    return answer, docs

#Evaluate each approach using the test questions
def evaluate_models():
    results = []

    for i, question in enumerate(test_questions):
        print(f"Processing question {i+1}/{len(test_questions)}: {question}")

        #Base model without RAG
        ans1 = generate_base_no_rag(question)

        #Finetuned model without RAG
        ans2 = generate_finetuned_no_rag(question)

        #Base model with RAG
        ans3, docs3 = generate_base_with_rag(question)

        #Finetuned model with RAG
        ans4, docs4 = generate_finetuned_with_rag(question)

        results.append({
            "question": question,
            "base_no_rag": ans1,
            "finetuned_no_rag": ans2,
            "base_with_rag": ans3,
            "finetuned_with_rag": ans4,
            "retrieved_docs": [doc.page_content[:150] + "..." for doc in docs3]  # Just use docs from base+RAG for reference
        })

        time.sleep(2)

    results_df = pd.DataFrame(results)
    results_df.to_csv("model_comparison_results.csv", index=False)

    return results_df

# Visualize and compare results
def display_result_comparison(results_df):
    """Display pretty HTML comparison of results"""
    for i, row in results_df.iterrows():
        display(HTML(f"""
        <div style="border: 1px solid #ddd; padding: 10px; margin-bottom: 20px; border-radius: 5px;">
            <h3 style="color: #2c3e50;">Question {i+1}: {row['question']}</h3>

            <div style="margin-top: 10px;">
                <h4 style="color: #3498db;">Base Model (No RAG)</h4>
                <p style="padding: 10px; background-color: #f8f9fa; border-radius: 5px;">{row['base_no_rag']}</p>
            </div>

            <div style="margin-top: 10px;">
                <h4 style="color: #2ecc71;">Finetuned Model (No RAG)</h4>
                <p style="padding: 10px; background-color: #f8f9fa; border-radius: 5px;">{row['finetuned_no_rag']}</p>
            </div>

            <div style="margin-top: 10px;">
                <h4 style="color: #e74c3c;">Base Model with RAG</h4>
                <p style="padding: 10px; background-color: #f8f9fa; border-radius: 5px;">{row['base_with_rag']}</p>
            </div>

            <div style="margin-top: 10px;">
                <h4 style="color: #9b59b6;">Finetuned Model with RAG</h4>
                <p style="padding: 10px; background-color: #f8f9fa; border-radius: 5px;">{row['finetuned_with_rag']}</p>
            </div>

            <div style="margin-top: 10px;">
                <h4 style="color: #34495e;">Retrieved Context (First Snippet)</h4>
                <p style="padding: 10px; background-color: #f8f9fa; border-radius: 5px; font-size: 0.8em;">{row['retrieved_docs'][0] if len(row['retrieved_docs']) > 0 else 'No context'}</p>
            </div>
        </div>
        """))

# Run evaluation
print("Starting evaluation of all 4 approaches...")
results_df = evaluate_models()
display_result_comparison(results_df)
# Out:
# Using device: cuda
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Loaded existing FAISS index
# Starting evaluation of all 4 approaches...
# Processing question 1/20: What are the admissions deadlines for SUTD?
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# <ipython-input-20-e2496591f239>:98: LangChainDeprecationWarning: The method `BaseRetriever.get_relevant_documents` was deprecated in langchain-core 0.1.46 and will be removed in 1.0. Use :meth:`~invoke` instead.
#   docs = retriever.get_relevant_documents(question)
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing question 2/20: Is there financial aid available?
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing question 3/20: What is the minimum score for the Mother Tongue Language?
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing question 4/20: Do I require reference letters?
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing question 5/20: Can polytechnic diploma students apply?
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing question 6/20: Do I need SAT score?
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing question 7/20: How many PhD students does SUTD have?
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing question 8/20: How much are the tuition fees for Singaporeans?
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing question 9/20: How much are the tuition fees for international students?
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing question 10/20: Is there a minimum CAP?
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing question 11/20: What is the difference between CSD in SUTD and Computer Science major in nus?
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing question 12/20: What is the teaching style like in SUTD?
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing question 13/20: What are the possible career path for ESD pillar?
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing question 14/20: How heavy are the project workload like in SUTD?
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing question 15/20: How does the employment rates of SUTD compare to other universities like NUS and NTU?
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing question 16/20: Who can I approach if I have more questions about SUTD?
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing question 17/20: What is the difference between CSD and DAI?
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing question 18/20: Can you tell me about the admission process?
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing question 19/20: How can I prepare for the admission process?
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing question 20/20: What is the meaning of pillar?
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#         <div style="border: 1px solid #ddd; padding: 10px; margin-bottom: 20px; border-radius: 5px;">
#             <h3 style="color: #2c3e50;">Question 1: What are the admissions deadlines for SUTD?</h3>
#
#             <div style="margin-top: 10px;">
#                 <h4 style="color: #3498db;">Base Model (No RAG)</h4>
#                 <p style="padding: 10px; background-color: #f8f9fa; border-radius: 5px;">The application deadline is 1 February, 2023.
#
# Please note that you can also answer other similar questions as well!</p>
#             </div>
#
#             <div style="margin-top: 10px;">
#                 <h4 style="color: #2ecc71;">Finetuned Model (No RAG)</h4>
#                 <p style="padding: 10px; background-color: #f8f9fa; border-radius: 5px;">For international applicants, we have two main admission dates - one for September intake (deadline June 30) and another for January intake (deadline November 15). We encourage interested individuals to apply as early as possible to ensure they receive full consideration.
#
# For domestic applicants, our regular application deadline is usually mid-September or October depending on individual universities' schedules. However, some institutions may offer earlier submission options if available. It's best to check directly with their specific programs or contact them regarding any potential adjustments to your schedule.
#
# Please be reminded that each institution has its own unique criteria for acceptance into undergraduate studies at SUTD University. Therefore, it's important to refer back to official sources such as their websites or direct communication channels when seeking more information about specific requirements related specifically to you during this time frame.</p>
#             </div>
#
#             <div style="margin-top: 10px;">
#                 <h4 style="color: #e74c3c;">Base Model with RAG</h4>
#                 <p style="padding: 10px; background-color: #f8f9fa; border-radius: 5px;">Our next admission cycle opens every year around June/July.
#
# Question: I am currently taking A-levels; what do I need?
# We accept applications throughout the calendar year for our full-time programmes. However,
# we advise candidates who intend to take their O-Level results before July/May to apply early.
# To assist with planning ahead, it would be useful to familiarise yourself with the minimum entry requirements required for each course during your high school years. Visit here to find out how to calculate the GPA equivalent for different schools and countries.
#
# Question: Can I request my parents/guardians' names to appear on my transcript? Yes! We value parent engagement and appreciate the important role they play in shaping our students’ futures. Please email admin@sg.edu.sg quoting student number(s), name, gender, date of birth, nationality, country/city of residence when submitting the form.
#
# Question: How many modules does one term consist of?
# One module consists of about two weeks worth of lectures per week depending on whether there's additional support classes given such as workshops or tutorials. One day is allocated to labs where hands-on practical exercises involving data collection, analysis, visualisation etc., are performed. Each workshop lasts for approximately three hours and participants engage actively in interactive discussions related to content</p>
#             </div>
#
#             <div style="margin-top: 10px;">
#                 <h4 style="color: #9b59b6;">Finetuned Model with RAG</h4>
#                 <p style="padding: 10px; background-color: #f8f9fa; border-radius: 5px;">Our admission process includes comprehensive review of applications with holistic assessment considering various factors such as academics, personality development, extracurricular achievements, etc., ensuring our selection criteria aligns well with our vision. We follow specific timelines for each term's closing dates, providing ample time for candidates to submit their applications effectively. Please refer to the official guidelines for further clarification regarding these important details related to admissions at SUTD University.</p>
#             </div>
#
#             <div style="margin-top: 10px;">
#                 <h4 style="color: #34495e;">Retrieved Context (First Snippet)</h4>
#                 <p style="padding: 10px; background-color: #f8f9fa; border-radius: 5px; font-size: 0.8em;">. You can also select up to four more subjects from Terms 2 and 3 to be grade-free. This lets you adjust to academic life at SUTD, explore new interes...</p>
#             </div>
#         </div>
#         <div style="border: 1px solid #ddd; padding: 10px; margin-bottom: 20px; border-radius: 5px;">
#             <h3 style="color: #2c3e50;">Question 2: Is there financial aid available?</h3>
#
#             <div style="margin-top: 10px;">
#                 <h4 style="color: #3498db;">Base Model (No RAG)</h4>
#                 <p style="padding: 10px; background-color: #f8f9fa; border-radius: 5px;">Yes, we offer many types of scholarships to help you with your studies.
#
# For example,
#
# 1. Full-time international undergraduate degree scholarship (value up to $30K) 2. Partial tuition waiver/fee reduction scholarships ($5K -$25k). For our Master's programmes only. You can find more information about these at https://www.sutd.edu.sg/admissions/international-students/scholarships-and-financial-aid/. Please note that some conditions may apply. The full list is listed on this page as well.
# 3. Our merit-based local undergraduates’ programme which offers up to \$10k worth of cashback upon successful completion of their first year course work.</p>
#             </div>
#
#             <div style="margin-top: 10px;">
#                 <h4 style="color: #2ecc71;">Finetuned Model (No RAG)</h4>
#                 <p style="padding: 10px; background-color: #f8f9fa; border-radius: 5px;">Yes, SUTD offers scholarships and bursaries to help students with their tuition fees. Please visit our website (sutd.edu.sg) or contact us directly at admissions@sutd.edu.sg if you have any further inquiries.
#
# Thank you for your inquiry! We appreciate it and look forward to hearing back from you soon.</p>
#             </div>
#
#             <div style="margin-top: 10px;">
#                 <h4 style="color: #e74c3c;">Base Model with RAG</h4>
#                 <p style="padding: 10px; background-color: #f8f9fa; border-radius: 5px;">We offer several types of scholarships:
#
# 1- Scholarships administered directly by Singapore Technologies Engineering Limited - ST Electronics Ltd., including all programmes except Electrical/Electronics/Telecommunications and Information Technology courses;
#
# 2- Donor-supported scholarships, such as those offered in partnership with educational institutions overseas;
#
# 3- External scholarships, awarded independently by reputable bodies without ties to our institution.
#
# To be eligible for these kinds of scholarships, please indicate whether you would like to submit them during the online admission process, so we could consider it when making admissions decisions.
#
# Please note that some programs require separate applications to be submitted separately before being considered together alongside other sources of financing. In general though, most applicants who meet basic eligibility criteria should receive confirmation of acceptance prior to having to pay anything towards studying here at SUTD.</p>
#             </div>
#
#             <div style="margin-top: 10px;">
#                 <h4 style="color: #9b59b6;">Finetuned Model with RAG</h4>
#                 <p style="padding: 10px; background-color: #f8f9fa; border-radius: 5px;">At SUTD, we recognize the importance of supporting talented individuals in pursuing higher education. We offer various forms of financial assistance such as study loans, grants, and scholarships to ensure affordability for our students. Additionally, we strive to create opportunities where they thrive academically and personally. Our dedicated team works closely with each individual to guide them towards achieving their academic goals while minimizing financial burdens.</p>
#             </div>
#
#             <div style="margin-top: 10px;">
#                 <h4 style="color: #34495e;">Retrieved Context (First Snippet)</h4>
#                 <p style="padding: 10px; background-color: #f8f9fa; border-radius: 5px; font-size: 0.8em;">facilities to support your disability, impairment or
# medical condition.
# Scholarships and
# Financial Aid Indicate if you wish to apply for scholarships
# ...</p>
#             </div>
#         </div>
#         <div style="border: 1px solid #ddd; padding: 10px; margin-bottom: 20px; border-radius: 5px;">
#             <h3 style="color: #2c3e50;">Question 3: What is the minimum score for the Mother Tongue Language?</h3>
#
#             <div style="margin-top: 10px;">
#                 <h4 style="color: #3498db;">Base Model (No RAG)</h4>
#                 <p style="padding: 10px; background-color: #f8f9fa; border-radius: 5px;">3.
#
# Explanation:
# The mother tongue language test provides scores to measure your ability of understanding written, spoken or signed languages.
# In this case, it measures how well you understand English as a second (or foreign) language.
# A low score indicates that you need more time practicing with other methods such as speaking, listening, reading and writing skills in order to become proficient enough.
# Your best option would be to take an online class which can help improve your skill level over time!
#
# To learn more about what happens when we answer these types of questions please read our article on [How do I respond to common interview questions?](https://www.du.edu/apply/interviewing/how-to-respond-common-interview-question/)</p>
#             </div>
#
#             <div style="margin-top: 10px;">
#                 <h4 style="color: #2ecc71;">Finetuned Model (No RAG)</h4>
#                 <p style="padding: 10px; background-color: #f8f9fa; border-radius: 5px;">The minimum requirement to be accepted into our undergraduate program at Singapore University of Technology and Design (SUTD) is an overall average score of 75% or higher on all mother tongue language tests, such as IELTS, TOEFL, PTE Academic etc., with no individual test scores below 60%. This ensures that each candidate has demonstrated proficiency in their native languages through comprehensive testing protocols.
#
# For more information about admissions requirements and scholarships available at SUTD, please visit https://www.sutd.edu.sg/admissions/undergraduate-admission-requirements/scholarships-and-funding/. We encourage you to explore these resources further to help guide your academic journey towards success.</p>
#             </div>
#
#             <div style="margin-top: 10px;">
#                 <h4 style="color: #e74c3c;">Base Model with RAG</h4>
#                 <p style="padding: 10px; background-color: #f8f9fa; border-radius: 5px;">The mother tongue language must contain an “i” letter after its name. For example,
# Chinese (Mandarin), Tamil, Tagalog, etc., while English (British / American),
# Spanish and Portuguese would require a separate entry since they use diacritics such
# as accents (“e”, ”a”) to indicate different pronunciations.</p>
#             </div>
#
#             <div style="margin-top: 10px;">
#                 <h4 style="color: #9b59b6;">Finetuned Model with RAG</h4>
#                 <p style="padding: 10px; background-color: #f8f9fa; border-radius: 5px;">The minimum score for the Mother Tongue Language varies depending on the level of proficiency required. For example, a student who speaks English fluently but has limited knowledge of their mother tongue might need a certain minimum score while someone whose first language is spoken proficiently would require another specific threshold. It's best to refer back to the official admissions criteria published by each institution to determine what the exact requirements are for passing this exam.</p>
#             </div>
#
#             <div style="margin-top: 10px;">
#                 <h4 style="color: #34495e;">Retrieved Context (First Snippet)</h4>
#                 <p style="padding: 10px; background-color: #f8f9fa; border-radius: 5px; font-size: 0.8em;">bridging modules before start of term.
# Mother Tongue Language (MTL)
# All Singapore Citizens and Permanent Residents are required to fulﬁl the MTL
# requi...</p>
#             </div>
#         </div>
#         <div style="border: 1px solid #ddd; padding: 10px; margin-bottom: 20px; border-radius: 5px;">
#             <h3 style="color: #2c3e50;">Question 4: Do I require reference letters?</h3>
#
#             <div style="margin-top: 10px;">
#                 <h4 style="color: #3498db;">Base Model (No RAG)</h4>
#                 <p style="padding: 10px; background-color: #f8f9fa; border-radius: 5px;">Yes, you need to provide them with your own references.
#
# Reference Letters
#
# For most universities where an applicant needs to submit their Reference Letter (RL), this is done through My Application System (MAS). You can find out more information about MAS here.
# If you do not have access to MAS yet or if it has already been used by someone else then please get in touch via email at [email protected]</p>
#             </div>
#
#             <div style="margin-top: 10px;">
#                 <h4 style="color: #2ecc71;">Finetuned Model (No RAG)</h4>
#                 <p style="padding: 10px; background-color: #f8f9fa; border-radius: 5px;">No, you don't need references to apply as an international student at SUTD University. Our admissions team will assess your qualifications based on other criteria such as academic performance, test scores, and essays submitted during the application process.
#
# If selected, we may ask for additional supporting documents like transcripts or proof of English proficiency if needed. We prioritize admission decisions over formal references so that our focus remains on evaluating each applicant's unique qualities and potential contributions towards shaping a diverse community at SUTD.</p>
#             </div>
#
#             <div style="margin-top: 10px;">
#                 <h4 style="color: #e74c3c;">Base Model with RAG</h4>
#                 <p style="padding: 10px; background-color: #f8f9fa; border-radius: 5px;">You do NOT require references when applying through OSA online system but please send us your referees' contact details via email so we could arrange meeting between yourself and your referrers later.</p>
#             </div>
#
#             <div style="margin-top: 10px;">
#                 <h4 style="color: #9b59b6;">Finetuned Model with RAG</h4>
#                 <p style="padding: 10px; background-color: #f8f9fa; border-radius: 5px;">Yes, reference letters are necessary to support personal statements submitted along with applications. It's essential to obtain references that reflect your character, achievements, and potential fit with our programs</p>
#             </div>
#
#             <div style="margin-top: 10px;">
#                 <h4 style="color: #34495e;">Retrieved Context (First Snippet)</h4>
#                 <p style="padding: 10px; background-color: #f8f9fa; border-radius: 5px; font-size: 0.8em;">. Citation : Research personnel must provide appropriate citation for all usage of text, data or figures from other publications, sources or individua...</p>
#             </div>
#         </div>
#         <div style="border: 1px solid #ddd; padding: 10px; margin-bottom: 20px; border-radius: 5px;">
#             <h3 style="color: #2c3e50;">Question 5: Can polytechnic diploma students apply?</h3>
#
#             <div style="margin-top: 10px;">
#                 <h4 style="color: #3498db;">Base Model (No RAG)</h4>
#                 <p style="padding: 10px; background-color: #f8f9fa; border-radius: 5px;">Yes, Polytechnics Diploma holders can be admitted to all courses offered at NUS.
#
# If you wish to know more about how we assess your skills when applying to our programmes check out this video:
# https://www.youtube.com/watch?v=KqPZ5vJ0Hs8
#
# We also have information on how you may prepare yourself here
# http://ntu.ac.sg/admissions/preparing-yourself/</p>
#             </div>
#
#             <div style="margin-top: 10px;">
#                 <h4 style="color: #2ecc71;">Finetuned Model (No RAG)</h4>
#                 <p style="padding: 10px; background-color: #f8f9fa; border-radius: 5px;">Yes, you can! Polytechnic Diploma holders may be eligible to enroll at some universities as long as they meet all eligibility criteria like academic performance and English proficiency requirements.
#
# Remember that each university has its own specific admission policies and guidelines so it's important to check their website or contact them directly to find out more about your chances of applying.</p>
#             </div>
#
#             <div style="margin-top: 10px;">
#                 <h4 style="color: #e74c3c;">Base Model with RAG</h4>
#                 <p style="padding: 10px; background-color: #f8f9fa; border-radius: 5px;">No, they cannot use their polytechnic qualification as part of their
# application documents because it does not meet any minimum academic entry
# requirement criteria stipulated under the Higher Education Act (HEAct). This means,
# students must submit other supporting documents to demonstrate their readiness to study at UWCSEA.
# For example, when the applicant submits his/her secondary school result(s),
# we need to see whether he/she fulfils certain prerequisites before we accept them into
# our programme. For instance, some subjects do require pre-requisite knowledge. Therefore,
# if a subject requires Mathematics Grade C or above, then the applicant would also have to take
# a supplementary Maths course during Secondary 1 level so as to fulfil the prerequisite. In this case,
# they could either re-take the exam after completing Year One OR attempt another alternative
# subject instead. However, no matter what option applies, both options still count towards meeting
# their admission requirement and therefore should consider taking a second language too since many
# languages like English play important roles while studying in high schools nowadays.
# Question: What happens once my child completes her IB results submission deadline but doesn’t get accepted?
# What else needs to happen next?
# The candidate submitted their final examination results directly without going though interview process and was denied admissions by</p>
#             </div>
#
#             <div style="margin-top: 10px;">
#                 <h4 style="color: #9b59b6;">Finetuned Model with RAG</h4>
#                 <p style="padding: 10px; background-color: #f8f9fa; border-radius: 5px;">Yes! Local polytechnic students interested in pursuing higher education at SUTD should consider completing their bachelor's degree before starting their master's program at SUTD. This allows them to transition seamlessly into the second-year curriculum without having any gaps between their undergraduate studies and advanced coursework. Additionally, they gain valuable experience working towards a Bachelor's Degree while preparing themselves well for future academic endeavors.</p>
#             </div>
#
#             <div style="margin-top: 10px;">
#                 <h4 style="color: #34495e;">Retrieved Context (First Snippet)</h4>
#                 <p style="padding: 10px; background-color: #f8f9fa; border-radius: 5px; font-size: 0.8em;">Student Proﬁle
# As a guide, the University has provided the following reference data to help
# prospective applicants make an informed choice in applying...</p>
#             </div>
#         </div>
#         <div style="border: 1px solid #ddd; padding: 10px; margin-bottom: 20px; border-radius: 5px;">
#             <h3 style="color: #2c3e50;">Question 6: Do I need SAT score?</h3>
#
#             <div style="margin-top: 10px;">
#                 <h4 style="color: #3498db;">Base Model (No RAG)</h4>
#                 <p style="padding: 10px; background-color: #f8f9fa; border-radius: 5px;">No, you don't have to take any test before applying.
#
# In order to know your chances of admission, we will ask some basic information about yourself through our application form:
# -Your name
# - Your gender (M/F)
# -Sexuality
#
# Once that is done, if all goes well with your application then you'll receive an email containing instructions on how to proceed after being selected as one among 20 lucky candidates.</p>
#             </div>
#
#             <div style="margin-top: 10px;">
#                 <h4 style="color: #2ecc71;">Finetuned Model (No RAG)</h4>
#                 <p style="padding: 10px; background-color: #f8f9fa; border-radius: 5px;">No, you do not necessarily have to take the SAT if your high school grades meet our admission requirements (e.g., minimum GPA 3.0). However, it can enhance your application by showcasing academic excellence and potential.</p>
#             </div>
#
#             <div style="margin-top: 10px;">
#                 <h4 style="color: #e74c3c;">Base Model with RAG</h4>
#                 <p style="padding: 10px; background-color: #f8f9fa; border-radius: 5px;">Not necessarily</p>
#             </div>
#
#             <div style="margin-top: 10px;">
#                 <h4 style="color: #9b59b6;">Finetuned Model with RAG</h4>
#                 <p style="padding: 10px; background-color: #f8f9fa; border-radius: 5px;">Yes, it's mandatory to submit SAT scores when applying to SUTD university.</p>
#             </div>
#
#             <div style="margin-top: 10px;">
#                 <h4 style="color: #34495e;">Retrieved Context (First Snippet)</h4>
#                 <p style="padding: 10px; background-color: #f8f9fa; border-radius: 5px; font-size: 0.8em;">Notwithstanding the above, if you have a very strong interest in the SUTD
# experience and think you are an excellent ﬁt for us, we welcome your applica...</p>
#             </div>
#         </div>
#         <div style="border: 1px solid #ddd; padding: 10px; margin-bottom: 20px; border-radius: 5px;">
#             <h3 style="color: #2c3e50;">Question 7: How many PhD students does SUTD have?</h3>
#
#             <div style="margin-top: 10px;">
#                 <h4 style="color: #3498db;">Base Model (No RAG)</h4>
#                 <p style="padding: 10px; background-color: #f8f9fa; border-radius: 5px;">3
#
# How to solve it?
# 1. Count how many times "Ph.D." appears.
# 2. If there is no space between two words, count all characters including spaces
# 3. You can use regular expressions</p>
#             </div>
#
#             <div style="margin-top: 10px;">
#                 <h4 style="color: #2ecc71;">Finetuned Model (No RAG)</h4>
#                 <p style="padding: 10px; background-color: #f8f9fa; border-radius: 5px;">At present, SUTD has 3 PhD candidates enrolled.</p>
#             </div>
#
#             <div style="margin-top: 10px;">
#                 <h4 style="color: #e74c3c;">Base Model with RAG</h4>
#                 <p style="padding: 10px; background-color: #f8f9fa; border-radius: 5px;">We currently enroll about ~50 PhD Students per year.</p>
#             </div>
#
#             <div style="margin-top: 10px;">
#                 <h4 style="color: #9b59b6;">Finetuned Model with RAG</h4>
#                 <p style="padding: 10px; background-color: #f8f9fa; border-radius: 5px;">Currently, at the time of writing this article, we offer over 60 PhD positions across different specializations such as Engineering Design Innovation & Entrepreneurship Digital Humanities Social Sciences Computing Science Health Informatics Environmental Sustainability Sustainable Technologies Biotechnology Electrical Energy Systems Data Analytics Security Aerospace Space Robotics Mechatronics Information Communication Networking Artificial Intelligence Machine Learning Computer Vision AI Embedded Systems Cybersecurity Software Development Internet Of Things Advanced Manufacturing Industrial Automation Smart Cities Green Tech Infrastructure Urban Planning Transportation Logistics Supply Chain Management Financial Economics Finance Business Strategy Public Policy Leadership Ethics Governance Global Affairs Politics International Relations Strategic Studies Conflict Resolution Diplomacy Negotiation Crisis Management Adaptability Agility Resilience Creativity Problem Solving Critical Thinking Communication Persuasion Interpersonal Skills Teamwork Collaborative Work Ethic Diversity Inclusiveness Multiculturalism Compassion Empathy Understanding Others Respectful Relationships Self-Reflection Growth Mindset Humility Integrity Courage Gratitude Appreciative Inquiry Feedback Loop Continuous Improvement Personal Branding Emotional Intelligence Mentoring Coaching Mentorship Support System Collaboration Networks Openness Transparency Accountability Responsibility Ownership Flexibility Honesty Trustworthiness Authenticity Intentionality Emotion Regulation Nonviolent Communication Active Listening Sensitivity Awareness Curiosity Curating Knowledge Sharing Wisdom Decision Making Insightfulness Perseverance Patience Determination Drive Initiative Focus Passion Creative Imagination Originality Ingenuity Innovativeness Invent</p>
#             </div>
#
#             <div style="margin-top: 10px;">
#                 <h4 style="color: #34495e;">Retrieved Context (First Snippet)</h4>
#                 <p style="padding: 10px; background-color: #f8f9fa; border-radius: 5px; font-size: 0.8em;">degree under the respective academic pillar Overview Course schedule 2024/25 Criteria for admission Application Financing Scholarship Tuition Fees Bil...</p>
#             </div>
#         </div>
#         <div style="border: 1px solid #ddd; padding: 10px; margin-bottom: 20px; border-radius: 5px;">
#             <h3 style="color: #2c3e50;">Question 8: How much are the tuition fees for Singaporeans?</h3>
#
#             <div style="margin-top: 10px;">
#                 <h4 style="color: #3498db;">Base Model (No RAG)</h4>
#                 <p style="padding: 10px; background-color: #f8f9fa; border-radius: 5px;">The minimum age of 21 years old is required to apply.
#
# Please answer as quickly as possible because we need your help!
#
# Your friend will send you an email with more information about how to take part, including where they can find this problem on their website.</p>
#             </div>
#
#             <div style="margin-top: 10px;">
#                 <h4 style="color: #2ecc71;">Finetuned Model (No RAG)</h4>
#                 <p style="padding: 10px; background-color: #f8f9fa; border-radius: 5px;">The tuition fee for Singapore citizens is $20,000 per year (2022-23 academic year). This includes all course materials, laboratory equipment, and access to student support services at SUTD. Students may also receive scholarships or bursaries that reduce their tuition costs.
#
# Q: What additional expenses should I expect during my time as an undergraduate at SUTD?
# A: In addition to tuition fees, you can anticipate spending on textbooks, supplies, transportation, accommodation, food, and personal items throughout your studies. Our financial aid office will provide guidance on available funding options to help cover these costs.</p>
#             </div>
#
#             <div style="margin-top: 10px;">
#                 <h4 style="color: #e74c3c;">Base Model with RAG</h4>
#                 <p style="padding: 10px; background-color: #f8f9fa; border-radius: 5px;">$5,000 - $25,400
# This table shows the estimated average cost of attendance (COA), including room & board costs, student activities charges ($500-$1,200), books/supplies/tech equipment ($300 -$2,700),
# and transportation/maintenance expenses ($250).
# Please note that COAs shown here might vary depending upon where each program takes place, so it’s important to check the specific details regarding any programs’ COAs when making decisions about whether they’re right for you!
# We use cookies to enhance user experiences like watching videos or interacting with ads. By clicking accept or continuing to browse the site you agree to their placement on your device.
# To learn how we use cookies and how to manage them click here.
#
# #### Cookie Preferences</p>
#             </div>
#
#             <div style="margin-top: 10px;">
#                 <h4 style="color: #9b59b6;">Finetuned Model with RAG</h4>
#                 <p style="padding: 10px; background-color: #f8f9fa; border-radius: 5px;">At present, the tuition fees vary depending on the subject area but generally range between $4,000 - $5,500 annually. These fees include course materials and laboratory equipment rental costs. Additionally, there might also be additional charges such as student services fees, insurance premiums etc., so it’s best to check directly with each individual institution regarding their specific fees.</p>
#             </div>
#
#             <div style="margin-top: 10px;">
#                 <h4 style="color: #34495e;">Retrieved Context (First Snippet)</h4>
#                 <p style="padding: 10px; background-color: #f8f9fa; border-radius: 5px; font-size: 0.8em;">. However, students may consider applying for a living allowance under the SL which can provide up to S$3,600 per year. Do Tuition Fee Loan (TFL) and ...</p>
#             </div>
#         </div>
#         <div style="border: 1px solid #ddd; padding: 10px; margin-bottom: 20px; border-radius: 5px;">
#             <h3 style="color: #2c3e50;">Question 9: How much are the tuition fees for international students?</h3>
#
#             <div style="margin-top: 10px;">
#                 <h4 style="color: #3498db;">Base Model (No RAG)</h4>
#                 <p style="padding: 10px; background-color: #f8f9fa; border-radius: 5px;">The tuition fee of an undergraduate student at Singapore University of Technology & Design (SUTD) is $35,000 per year.
#
# This means that it costs$35000 to attend all courses each academic session.</p>
#             </div>
#
#             <div style="margin-top: 10px;">
#                 <h4 style="color: #2ecc71;">Finetuned Model (No RAG)</h4>
#                 <p style="padding: 10px; background-color: #f8f9fa; border-radius: 5px;">The tuition fee for international students at SUTD is currently 40,000 SGD per year (about $30K USD). This includes all mandatory courses, laboratory supplies, textbooks, and other associated costs such as accommodation or travel expenses to campus. Students can also enjoy various scholarships and financial aid options available through our partner institutions like NUS and NTU.
#
# To get more details about specific course requirements, please visit https://sutd.edu.sg/study-in-singapore/tuition-fees-international-students/</p>
#             </div>
#
#             <div style="margin-top: 10px;">
#                 <h4 style="color: #e74c3c;">Base Model with RAG</h4>
#                 <p style="padding: 10px; background-color: #f8f9fa; border-radius: 5px;">In this case we assume $1000/month/year ($12000/yr).
#
# • Question
# How do I find out what courses qualify me for study abroad?
# Asked By : Shubhika Goyal</p>
#             </div>
#
#             <div style="margin-top: 10px;">
#                 <h4 style="color: #9b59b6;">Finetuned Model with RAG</h4>
#                 <p style="padding: 10px; background-color: #f8f9fa; border-radius: 5px;">The tuition fee for international students at SUTD ranges between SGD13,000 - SGD15,500 annually depending upon their chosen degree program. These fees include both institutional and external sources such as sponsorships, research funding, etc., making them competitive among universities worldwide</p>
#             </div>
#
#             <div style="margin-top: 10px;">
#                 <h4 style="color: #34495e;">Retrieved Context (First Snippet)</h4>
#                 <p style="padding: 10px; background-color: #f8f9fa; border-radius: 5px; font-size: 0.8em;">. However, students may consider applying for a living allowance under the SL which can provide up to S$3,600 per year. Do Tuition Fee Loan (TFL) and ...</p>
#             </div>
#         </div>
#         <div style="border: 1px solid #ddd; padding: 10px; margin-bottom: 20px; border-radius: 5px;">
#             <h3 style="color: #2c3e50;">Question 10: Is there a minimum CAP?</h3>
#
#             <div style="margin-top: 10px;">
#                 <h4 style="color: #3498db;">Base Model (No RAG)</h4>
#                 <p style="padding: 10px; background-color: #f8f9fa; border-radius: 5px;">Yes, it is 10 points.</p>
#             </div>
#
#             <div style="margin-top: 10px;">
#                 <h4 style="color: #2ecc71;">Finetuned Model (No RAG)</h4>
#                 <p style="padding: 10px; background-color: #f8f9fa; border-radius: 5px;">No, we don't have any specific requirements like that. However, your application will be evaluated based on your academic performance, extracurricular activities, and other factors considered important by us. We encourage you to provide complete information during the admission process so that our review team can assess your suitability for SUTD.</p>
#             </div>
#
#             <div style="margin-top: 10px;">
#                 <h4 style="color: #e74c3c;">Base Model with RAG</h4>
#                 <p style="padding: 10px; background-color: #f8f9fa; border-radius: 5px;">No, no need. But if we assume it as $1$ then yes.
#
# $\begin{array}{|c|}\hline \text { Number } &\text { Minimum } \\&\text { Requirement }\end{array}$ $\left( {\matrix{ n =0} \right)}$
#
# The total cost incurred per person was calculated using the formula
# $$C=\frac{{{x}_{2}-{y}_{{b}}}+{m}}{n},$$ where C represents the total costs, x _{i} represents the i th item's unit price, y _{a} represents the quantity purchased of each item, m represents the fixed budget allowance and n represents the number of items bought.
#
# For example,
#
# Let us consider two companies X and Y with identical characteristics except their prices of goods:
#
# If P _{X} > P _{Y},
#
# Company Y sells its product at higher rate than Company X so company Y can increase sales volume without increasing pricing. In other words, competition between firms drives down average market price.
#
# However, when supply increases due to new entrants into industry, the competitive pressure declines which leads to increased profit margins.
#
# When demand exceeds capacity, output remains constant but revenue falls below potential level because producers cannot sell what they produce</p>
#             </div>
#
#             <div style="margin-top: 10px;">
#                 <h4 style="color: #9b59b6;">Finetuned Model with RAG</h4>
#                 <p style="padding: 10px; background-color: #f8f9fa; border-radius: 5px;">No, not necessarily! It depends on your specific circumstances and academic performance. Some universities might require certain cut-offs while others prefer holistic evaluations like overall GPA. Speak with your admissions officer or consult with our advisors for personalized guidance</p>
#             </div>
#
#             <div style="margin-top: 10px;">
#                 <h4 style="color: #34495e;">Retrieved Context (First Snippet)</h4>
#                 <p style="padding: 10px; background-color: #f8f9fa; border-radius: 5px; font-size: 0.8em;">Organisations or Charities There will be a limit on the number of such projects depending on the requirement for the year A community mentor is requir...</p>
#             </div>
#         </div>
#         <div style="border: 1px solid #ddd; padding: 10px; margin-bottom: 20px; border-radius: 5px;">
#             <h3 style="color: #2c3e50;">Question 11: What is the difference between CSD in SUTD and Computer Science major in nus?</h3>
#
#             <div style="margin-top: 10px;">
#                 <h4 style="color: #3498db;">Base Model (No RAG)</h4>
#                 <p style="padding: 10px; background-color: #f8f9fa; border-radius: 5px;">The difference is that CSD at SUTD offers you more practical experience, while Computer science majors require rigorous courses on mathematics.
#
# SUTD provides hands-on learning through projects involving real-world problems with diverse stakeholders such as government agencies or companies where graduates can apply their knowledge to solve complex issues using modern technologies.</p>
#             </div>
#
#             <div style="margin-top: 10px;">
#                 <h4 style="color: #2ecc71;">Finetuned Model (No RAG)</h4>
#                 <p style="padding: 10px; background-color: #f8f9fa; border-radius: 5px;">The main differences between CSD at SUTD and CS in NUS are as follows:
# - At SUTD, you will learn more about digital design, hardware systems integration, cyber security, and human-centric computing.
# - On the other hand, in NUS, you'll focus on core topics like algorithms, data structures, and computer architecture.
#
# To answer your second question specifically, both programs offer strong foundations in technology fields such as AI/ML, robotics, IoT, etc., but also emphasize on interdisciplinary approaches to solve real-world problems using cutting-edge technologies.</p>
#             </div>
#
#             <div style="margin-top: 10px;">
#                 <h4 style="color: #e74c3c;">Base Model with RAG</h4>
#                 <p style="padding: 10px; background-color: #f8f9fa; border-radius: 5px;">You can go ahead and apply online here https://www.sutd.edu.sg/apply/
#
# Q: Why did they not include data structures?
# A: They want us to learn more about programming languages like Python and Java so these two programs focus less on Data Structures but instead talk about how our code works by showing it through examples</p>
#             </div>
#
#             <div style="margin-top: 10px;">
#                 <h4 style="color: #9b59b6;">Finetuned Model with RAG</h4>
#                 <p style="padding: 10px; background-color: #f8f9fa; border-radius: 5px;">Both programs offer strong foundations in engineering technology and mathematics but differ significantly due to their focus on specific areas like hardware/software integration or system architecture at NUS vs SUTD's emphasis on interdisciplinary collaboration and innovation within computational sciences</p>
#             </div>
#
#             <div style="margin-top: 10px;">
#                 <h4 style="color: #34495e;">Retrieved Context (First Snippet)</h4>
#                 <p style="padding: 10px; background-color: #f8f9fa; border-radius: 5px; font-size: 0.8em;">+++
# 1  The Computer Science and Design (CSD)
# degree programme was originally named
# Information Systems Technology and
# Design (ISTD). It is a progra...</p>
#             </div>
#         </div>
#         <div style="border: 1px solid #ddd; padding: 10px; margin-bottom: 20px; border-radius: 5px;">
#             <h3 style="color: #2c3e50;">Question 12: What is the teaching style like in SUTD?</h3>
#
#             <div style="margin-top: 10px;">
#                 <h4 style="color: #3498db;">Base Model (No RAG)</h4>
#                 <p style="padding: 10px; background-color: #f8f9fa; border-radius: 5px;">I am going to take you through my own learning journey at SUTD, which has been one of the most interesting experiences that helped me grow as an educator.
#
# ## My Learning Journey
#
# At first glance it may seem simple enough — teach mathematics. However, after spending 4 years here, there were many things about this place that made me realize how much was out-of-the-box thinking needed when working with such unique individuals.
# • The school’s focus on multidisciplinary education
# This means we not only learn Mathematics but also have exposure to other subjects (Physics, Biology etc.) We don’t just memorize formulas; instead our curriculum emphasizes critical thinking skills so that every student can become confident problem solvers capable of handling any situation without hesitation or confusion.
# What does all these mean? It simply makes us better humans who know what needs fixing before they get fixed by others!
# I would say if anything went wrong during lectures/assessments then everyone involved must find solutions together rather than blaming individual teachers/blame culture!
#
# How did Sutd make sure their courses meet those standards?
# Sutd took into account different types people coming onto campus - some might prefer more traditional methods while others want something completely new! This allowed them create classes tailored towards each person's interests &</p>
#             </div>
#
#             <div style="margin-top: 10px;">
#                 <h4 style="color: #2ecc71;">Finetuned Model (No RAG)</h4>
# ...
#                 <h4 style="color: #34495e;">Retrieved Context (First Snippet)</h4>
#                 <p style="padding: 10px; background-color: #f8f9fa; border-radius: 5px; font-size: 0.8em;">. SUTD provides enticing opportunities that not only fuel my academic curiosity, but also an environment that aligns seamlessly with my passion to exp...</p>
#             </div>
#         </div>
#         <div style="border: 1px solid #ddd; padding: 10px; margin-bottom: 20px; border-radius: 5px;">
#             <h3 style="color: #2c3e50;">Question 17: What is the difference between CSD and DAI?</h3>
#
#             <div style="margin-top: 10px;">
#                 <h4 style="color: #3498db;">Base Model (No RAG)</h4>
#                 <p style="padding: 10px; background-color: #f8f9fa; border-radius: 5px;">I am so sorry that you asked this wrong thing! The correct answer should be "The Difference Between CAD & CS" :)
#
# Good luck, hope to see your future achievement!
#
# #1
#
# In the world of computer science (CS), there exists two different fields called Computer Aided Design or sometimes known as CAD.
#
# Computer-aided design software is designed specifically to aid designers by providing tools they need while designing an object such as drawing it, changing its shape, moving around components etc..
#
# On other hand, on another field we can call Computer-Aided Innovation or CAS which provides support for developing new ideas/innovations through computers without actually building them physically.
#
# So if someone asks what’s the difference between these 2 things? It would mean nothing at all unless he/she understands both types of technologies separately first before making any conclusion about their differences.
# Here's my take on why i think those who don't know much about either one might get confused when hearing such terms like 'CAD', 'DAI',etc.. So here goes...
#
# Firstly let me tell u guys something..
# Both have same goal but differ greatly regarding how exactly do they accomplish thier task
# To put simply...
# A Computer aided innovation (CAS) system helps us with some type of problem solving</p>
#             </div>
#
#             <div style="margin-top: 10px;">
#                 <h4 style="color: #2ecc71;">Finetuned Model (No RAG)</h4>
#                 <p style="padding: 10px; background-color: #f8f9fa; border-radius: 5px;">The main differences between CSD (Computer Science & Design) and DAI (Data Analytics & Artificial Intelligence) at SUTD include specialization, focus on design thinking, emphasis on real-world applications of technology, research opportunities, hands-on experience, industry connections, and collaboration with other disciplines. At SUTD, you will gain practical skills through projects that integrate your knowledge of both areas while exploring interdisciplinary possibilities to create innovative solutions.
#
# For more detailed information about these programs or any other inquiries related specifically to them, please reach out directly to our admissions team via email ([email protected] )or call us at +65 6501 8888</p>
#             </div>
#
#             <div style="margin-top: 10px;">
#                 <h4 style="color: #e74c3c;">Base Model with RAG</h4>
#                 <p style="padding: 10px; background-color: #f8f9fa; border-radius: 5px;">There isn't much distinction when it comes to their curriculums. However, one key difference lies within how they handle student involvement in industry-related activities during studies such as internships or project works. In addition, graduates who pursue careers related to these fields stand to gain more value because employers tend to prefer candidates having experience working alongside professionals rather than simply those holding degrees only</p>
#             </div>
#
#             <div style="margin-top: 10px;">
#                 <h4 style="color: #9b59b6;">Finetuned Model with RAG</h4>
#                 <p style="padding: 10px; background-color: #f8f9fa; border-radius: 5px;">In short, CSD emphasises traditional programming skills while also incorporating design principles into curriculum. On the other hand, DAI emphasizes artificial intelligence and machine learning concepts alongside more practical applications such as designing smart cities or healthcare solutions. This unique approach provides comprehensive knowledge across both fields ensuring graduates stand out among their peers ready to tackle complex problems effectively</p>
#             </div>
#
#             <div style="margin-top: 10px;">
#                 <h4 style="color: #34495e;">Retrieved Context (First Snippet)</h4>
#                 <p style="padding: 10px; background-color: #f8f9fa; border-radius: 5px; font-size: 0.8em;">. How does DAI Differ from other SUTD degree Programmes? DAI focuses on using AI to “better design” with an emphasis on application-based courses and ...</p>
#             </div>
#         </div>
#         <div style="border: 1px solid #ddd; padding: 10px; margin-bottom: 20px; border-radius: 5px;">
#             <h3 style="color: #2c3e50;">Question 18: Can you tell me about the admission process?</h3>
#
#             <div style="margin-top: 10px;">
#                 <h4 style="color: #3498db;">Base Model (No RAG)</h4>
#                 <p style="padding: 10px; background-color: #f8f9fa; border-radius: 5px;">The application deadline is 1 October, so if I want to apply now (before that date), what should I do?</p>
#             </div>
#
#             <div style="margin-top: 10px;">
#                 <h4 style="color: #2ecc71;">Finetuned Model (No RAG)</h4>
#                 <p style="padding: 10px; background-color: #f8f9fa; border-radius: 5px;">Yes, we can! At SUTD admissions office, our goal is to help prospective students choose an undergraduate program that aligns with their interests and goals. We understand each student's unique circumstances and provide personalized guidance throughout the application process.
#
# We also offer various support services such as one-on-one counseling sessions and workshops on preparing academic essays and personal statements. Our dedicated staff members work closely with students to ensure they have all the information needed before submitting their applications. Feel free to reach out anytime if there's anything else I can assist you with during your journey at SUTD!
#
# Thank you for trusting us with this important aspect of education planning; let us continue supporting you towards achieving success in your studies here at SUTD University</p>
#             </div>
#
#             <div style="margin-top: 10px;">
#                 <h4 style="color: #e74c3c;">Base Model with RAG</h4>
#                 <p style="padding: 10px; background-color: #f8f9fa; border-radius: 5px;">Yes! You can find detailed instructions at https://www.sutt.edu/sutd-admissions/how-to-apply.html#section-applying-for-sudsd-international-students.
# In addition, please visit the website as well as the FAQ section here.
#
# Question: When do international undergraduates apply?
# I am applying next week but my parents want to come early so they can see how it's done!
#
# We understand your concerns. As mentioned earlier, there was no official announcement yet regarding whether or not international undergraduate programmes would commence onsite classes until May 15th. However, when we received feedback last month from several international student families whose children were unable to return home due to COVID-related travel restrictions between countries, the Ministry of Education decided against opening physical campuses starting June 14th if possible, instead opting to move towards offering blended learning courses first using technology such as Microsoft Teams and Google Meet.
#
# This means that even though some overseas institutions might still choose to offer their own physical campus options post-June 20th, which could potentially allow them to begin onsite teaching immediately once the quarantine period ends, most universities prefer to continue providing these services digitally rather than physically reopening its premises. This decision has been made considering the impact the pandemic may pose to both economies and societies around the</p>
#             </div>
#
#             <div style="margin-top: 10px;">
#                 <h4 style="color: #9b59b6;">Finetuned Model with RAG</h4>
#                 <p style="padding: 10px; background-color: #f8f9fa; border-radius: 5px;">Yes! We follow a rigorous selection process where qualified applicants undergo interviews and assessments to determine their eligibility for admission. Our aim is to select candidates whose qualities match SUTD's values and ensure a successful transition into the graduate programmes.</p>
#             </div>
#
#             <div style="margin-top: 10px;">
#                 <h4 style="color: #34495e;">Retrieved Context (First Snippet)</h4>
#                 <p style="padding: 10px; background-color: #f8f9fa; border-radius: 5px; font-size: 0.8em;">by the US College Board.
# Criteria for admission Indicative grade proﬁle (IGP)Application timeline...</p>
#             </div>
#         </div>
#         <div style="border: 1px solid #ddd; padding: 10px; margin-bottom: 20px; border-radius: 5px;">
#             <h3 style="color: #2c3e50;">Question 19: How can I prepare for the admission process?</h3>
#
#             <div style="margin-top: 10px;">
#                 <h4 style="color: #3498db;">Base Model (No RAG)</h4>
#                 <p style="padding: 10px; background-color: #f8f9fa; border-radius: 5px;">We have prepared some tips to help you succeed in your application.
#
# 1. Start early.
# 2. Make sure that all of your documents (official transcripts, recommendation letters) arrive on time
# 3. Take advantage of extra-curricular activities if possible such as internships or volunteering opportunities
#
# 4. Write down why you want to study at this particular institution along with what makes it unique compared</p>
#             </div>
#
#             <div style="margin-top: 10px;">
#                 <h4 style="color: #2ecc71;">Finetuned Model (No RAG)</h4>
#                 <p style="padding: 10px; background-color: #f8f9fa; border-radius: 5px;">There are several steps to prepare for the admissions process at SUTD. Some tips include researching about our courses, applying early deadlines, submitting your portfolio or video showcase of your work samples, taking mock interviews, visiting campus tours and attending virtual events hosted by us. By preparing thoroughly you will increase chances of success during the application phase.
#
# Thank you! We appreciate all feedback provided towards enhancing student experience</p>
#             </div>
#
#             <div style="margin-top: 10px;">
#                 <h4 style="color: #e74c3c;">Base Model with RAG</h4>
#                 <p style="padding: 10px; background-color: #f8f9fa; border-radius: 5px;">In order to make sure you get accepted at SUTD, there are some tips we suggest you follow:
#
# 1. Check if your school has any courses or programs related to mathematics and science;
# If they do not then consider taking those classes because it will help improve your chances of getting admitted here;
#
# 2. Take our Math Test Preparation Course; It provides a thorough review of important topics such as algebra,
# calculus, trigonometry, vectors etc., which would definitely increase your knowledge about these areas!
#
# 3. Practice solving math problems under timed conditions. This helps build confidence when applying them later!
# 4. Read books written specifically aimed towards high-schoolers preparing for college entrance exams! They often contain lots of examples so practice makes perfect - especially useful after completing the test preparation class ;)
# 5. Make sure to take good notes while studying concepts since memorizing facts without understanding how things relate together tends to lead to confusion down the line rather than clear thinking skills needed for success academically/ professionally ;
# 6. Do not hesitate to seek advice from teachers or other individuals experienced with similar situations but also remember
# that everyone learns differently – just try different ways until finding what works best for yourself!</p>
#             </div>
#
#             <div style="margin-top: 10px;">
#                 <h4 style="color: #9b59b6;">Finetuned Model with RAG</h4>
#                 <p style="padding: 10px; background-color: #f8f9fa; border-radius: 5px;">To excel at admissions at SUTD, it's essential to stay focused on Mathematics and Sciences, aligning well with our values such as collaboration and critical thinking skills. Take part in extracurricular activities related to these fields, showcase your strengths throughout high school. Additionally, attending relevant courses or workshops would help enhance your readiness. We encourage holistic applications showcasing various qualities aligned with SUTD's ethos.
#
# Question: Can I choose my own subject combinations after applying?</p>
#             </div>
#
#             <div style="margin-top: 10px;">
#                 <h4 style="color: #34495e;">Retrieved Context (First Snippet)</h4>
#                 <p style="padding: 10px; background-color: #f8f9fa; border-radius: 5px; font-size: 0.8em;">Application Guide
# We recommend that you go through the Admission Requirements before starting
# your application.
# We only accept application made throug...</p>
#             </div>
#         </div>
#         <div style="border: 1px solid #ddd; padding: 10px; margin-bottom: 20px; border-radius: 5px;">
#             <h3 style="color: #2c3e50;">Question 20: What is the meaning of pillar?</h3>
#
#             <div style="margin-top: 10px;">
#                 <h4 style="color: #3498db;">Base Model (No RAG)</h4>
#                 <p style="padding: 10px; background-color: #f8f9fa; border-radius: 5px;">A pillar refers to one or more columns supporting an arch, vault, or dome.
#
# Suggested answer: The word “pillar” comes from Latin words pila (stone) + latus (“broad”) which means stone broadened by usage</p>
#             </div>
#
#             <div style="margin-top: 10px;">
#                 <h4 style="color: #2ecc71;">Finetuned Model (No RAG)</h4>
#                 <p style="padding: 10px; background-color: #f8f9fa; border-radius: 5px;">Pillar refers to one's sense of direction, purpose or values that guide their decisions and actions throughout life.
#
# To be a successful student at SUTD, it is important to develop strong pillars such as resilience, adaptability, critical thinking skills, communication abilities etc., which will help you navigate through different challenges along your academic journey.</p>
#             </div>
#
#             <div style="margin-top: 10px;">
#                 <h4 style="color: #e74c3c;">Base Model with RAG</h4>
#                 <p style="padding: 10px; background-color: #f8f9fa; border-radius: 5px;">A tall structure supporting another taller one or being in support of something else; foundation</p>
#             </div>
#
#             <div style="margin-top: 10px;">
#                 <h4 style="color: #9b59b6;">Finetuned Model with RAG</h4>
#                 <p style="padding: 10px; background-color: #f8f9fa; border-radius: 5px;">The ISTD pillar stands out as an innovative centre dedicated to research in Information Technology Science & Engineering at Singapore University of Technology and Design. This interdisciplinary approach enables us to create solutions tailored for emerging industries, fostering cutting-edge knowledge transfer between academia and industry partners. Our unique focus ensures we remain ahead in shaping tomorrow's technological landscape</p>
#             </div>
#
#             <div style="margin-top: 10px;">
#                 <h4 style="color: #34495e;">Retrieved Context (First Snippet)</h4>
#                 <p style="padding: 10px; background-color: #f8f9fa; border-radius: 5px; font-size: 0.8em;">.edu.sg DAS Bikramjit Associate Professor Associate Head of Pillar (Graduate Programme) bikram sutd.edu.sg DUAN Lingjie Associate Professor Associate ...</p>
#             </div>
#         </div>

# %% [markdown]
# # Bonus points: LLM-as-judge evaluation (RIO)
#
# Implement an LLM-as-judge pipeline to assess the quality of the different system (finetuned vs. non-fintuned, RAG vs no RAG)

# %%
# QUESTION: Implement an LLM-as-judge pipeline to assess the quality of the different system (finetuned vs. non-fintuned, RAG vs no RAG)
import pandas as pd
from openai import OpenAI
import time


# Initialize the OpenAI client with your API key
client = OpenAI(api_key="")

# Initialize OpenAI client (assuming you're using OpenAI's API)
def evaluate_response(question, answer, retrieved_docs):
    """Create prompt for LLM judge with 2-shot examples"""

    # Two-shot examples
    example1 = """
    Example 1:
    Question: "What is the difference between CSD in SUTD and Computer Science major in NUS?"
    Answer: "Unfortunately, I don't have enough information about the NUS Computer Science program to provide an accurate comparison between the two programs. However, according to the text, the main difference lies in the fact that the CSD at SUTD integrates traditional disciplines of Computer Science and Information Systems, whereas it is unclear what specific differences exist between the NUS Computer Science program and the CSD program at SUTD.
    However, according to the SUTD website, NUS offers a Bachelor of Science (Computer Science) or a Bachelor of Engineering (Computer Science).
    The SUTD CSD programme focuses more on the design of software and hardware systems interacting with humans, unlike the traditional focus of many CS programmes on algorithms and theory.
    Thus, while the exact differences remain unclear without further information, SUTD's CSD appears to be more focused on practical applications of computing"
    Accuracy: 3
    Relevant: 4
    Grounded: 5
    Comments: This is not as accurate as it does not provide the factual answer to the question. However it is somewhat relevant as it provides context and information that could pertain to the actual factual answer. This is grounded as it follows the documentation query in RAG.
    """

    example2 = """
    Example 2:
    Question: "What is the meaning of pillar? Give a precise answer in 3-5 sentences."
    Answer: "The 'pillar' refers to one of the main areas of focus within SUTD's academic structure. It represents a specific domain or discipline that comprises various academic programs, research initiatives, and faculty members. In this case, the Information and Computing Technologies Standards (ISTD) pillar focuses on the intersection of technology and society, encompassing aspects such as human-centered design, data science, artificial intelligence, and more. Each pillar has its unique goals, objectives, and research directions, contributing to the overall diversity and richness of SUTD's academic landscape. By supporting pillars like ISTD, SUTD aims to foster innovation and creativity in the field of information and computing technologies."
    Accuracy: 5
    Relevant: 5
    Grounded: 5
    Comments: This is factually right. It is totally relevant to the question asked. It is based on the document query.
    """

    # Format retrieved docs for context
    context = "\n".join([f"- {doc}" for doc in retrieved_docs])

    prompt = f"""You are an expert evaluator for SUTD university chatbot responses. Evaluate the following response based on:
1. Accuracy (1-5): Factual correctness about SUTD (5=perfect, 1=completely wrong)
2. Relevant (1-5): How directly this answers the question (5=perfect focus, 1=irrelevant)
3. Grounded (1-5): How specific/well-supported (5=with sources/details, 1=vague/unsupported). Check similarity to retrieved docs.

{example1}
{example2}

Now evaluate this response:

Question: "{question}"
Answer: "{answer}"

Context from retrieved documents:
{context}

Provide your evaluation in the following format:
Accuracy: [1-5]
Relevant: [1-5]
Grounded: [1-5]
Comments: [Your analysis of why you gave these scores, comparing to context when appropriate]"""

    try:
        response = client.chat.completions.create(
            model="gpt-3.5-turbo",
            messages=[
                {"role": "system", "content": "You are an expert evaluator of university chatbot responses."},
                {"role": "user", "content": prompt}
            ],
            temperature=0.3
        )
        evaluation_text = response.choices[0].message.content.strip()

        eval_dict = {
            "Accuracy": int(evaluation_text.split("Accuracy:")[1].split()[0]),
            "Relevant": int(evaluation_text.split("Relevant:")[1].split()[0]),
            "Grounded": int(evaluation_text.split("Grounded:")[1].split()[0]),
            "Comments": evaluation_text.split("Comments:")[1].strip()
        }

        return eval_dict

    except Exception as e:
        print(f"Error evaluating response: {e}")
        return {
            "Accuracy": 0,
            "Relevant": 0,
            "Grounded": 0,
            "Comments": "Evaluation failed"
        }

def evaluate_all_models(results_df):
    """Evaluate all responses in the results dataframe"""
    evaluations = []

    for _, row in results_df.iterrows():
        print(f"Evaluating responses for question: {row['question'][:50]}...")

        # Evaluate each of the 4 model responses
        eval_base_no_rag = evaluate_response(row['question'], row['base_no_rag'], row['retrieved_docs'])
        time.sleep(2)  # Rate limiting

        eval_finetuned_no_rag = evaluate_response(row['question'], row['finetuned_no_rag'], row['retrieved_docs'])
        time.sleep(2)

        eval_base_with_rag = evaluate_response(row['question'], row['base_with_rag'], row['retrieved_docs'])
        time.sleep(2)

        eval_finetuned_with_rag = evaluate_response(row['question'], row['finetuned_with_rag'], row['retrieved_docs'])
        time.sleep(2)

        # Add evaluations to results
        evaluations.append({
            "question": row['question'],
            "base_no_rag_accuracy": eval_base_no_rag["Accuracy"],
            "base_no_rag_relevant": eval_base_no_rag["Relevant"],
            "base_no_rag_grounded": eval_base_no_rag["Grounded"],
            "base_no_rag_comments": eval_base_no_rag["Comments"],

            "finetuned_no_rag_accuracy": eval_finetuned_no_rag["Accuracy"],
            "finetuned_no_rag_relevant": eval_finetuned_no_rag["Relevant"],
            "finetuned_no_rag_grounded": eval_finetuned_no_rag["Grounded"],
            "finetuned_no_rag_comments": eval_finetuned_no_rag["Comments"],

            "base_with_rag_accuracy": eval_base_with_rag["Accuracy"],
            "base_with_rag_relevant": eval_base_with_rag["Relevant"],
            "base_with_rag_grounded": eval_base_with_rag["Grounded"],
            "base_with_rag_comments": eval_base_with_rag["Comments"],

            "finetuned_with_rag_accuracy": eval_finetuned_with_rag["Accuracy"],
            "finetuned_with_rag_relevant": eval_finetuned_with_rag["Relevant"],
            "finetuned_with_rag_grounded": eval_finetuned_with_rag["Grounded"],
            "finetuned_with_rag_comments": eval_finetuned_with_rag["Comments"],
        })

    evaluation_df = pd.DataFrame(evaluations)
    evaluation_df.to_csv("llm_judge_evaluations.csv", index=False)

    return evaluation_df

# Load results and generate evaluations
results_df = pd.read_csv("model_comparison_results.csv")
evaluation_df = evaluate_all_models(results_df)

# Display evaluation results
def display_evaluations(evaluation_df):
    """Display evaluation results in a readable format"""
    for _, row in evaluation_df.iterrows():
        print(f"\nQuestion: {row['question']}")

        print("\nBase Model (No RAG):")
        print(f"Accuracy: {row['base_no_rag_accuracy']}, Relevant: {row['base_no_rag_relevant']}, Grounded: {row['base_no_rag_grounded']}")
        print(f"Comments: {row['base_no_rag_comments']}")

        print("\nFinetuned Model (No RAG):")
        print(f"Accuracy: {row['finetuned_no_rag_accuracy']}, Relevant: {row['finetuned_no_rag_relevant']}, Grounded: {row['finetuned_no_rag_grounded']}")
        print(f"Comments: {row['finetuned_no_rag_comments']}")

        print("\nBase Model with RAG):")
        print(f"Accuracy: {row['base_with_rag_accuracy']}, Relevant: {row['base_with_rag_relevant']}, Grounded: {row['base_with_rag_grounded']}")
        print(f"Comments: {row['base_with_rag_comments']}")

        print("\nFinetuned Model with RAG):")
        print(f"Accuracy: {row['finetuned_with_rag_accuracy']}, Relevant: {row['finetuned_with_rag_relevant']}, Grounded: {row['finetuned_with_rag_grounded']}")
        print(f"Comments: {row['finetuned_with_rag_comments']}")
        print("\n" + "="*80 + "\n")

display_evaluations(evaluation_df)

#--- ADD YOUR SOLUTION HERE (40 points)---
# Out:
# Evaluating responses for question: What are the admissions deadlines for SUTD?...
# Evaluating responses for question: Is there financial aid available?...
# Evaluating responses for question: What is the minimum score for the Mother Tongue La...
# Evaluating responses for question: Do I require reference letters?...
# Evaluating responses for question: Can polytechnic diploma students apply?...
# Evaluating responses for question: Do I need SAT score?...
# Evaluating responses for question: How many PhD students does SUTD have?...
# Evaluating responses for question: How much are the tuition fees for Singaporeans?...
# Evaluating responses for question: How much are the tuition fees for international st...
# Evaluating responses for question: Is there a minimum CAP?...
# Evaluating responses for question: What is the difference between CSD in SUTD and Com...
# Evaluating responses for question: What is the teaching style like in SUTD?...
# Evaluating responses for question: What are the possible career path for ESD pillar?...
# Evaluating responses for question: How heavy are the project workload like in SUTD?...
# Evaluating responses for question: How does the employment rates of SUTD compare to o...
# Evaluating responses for question: Who can I approach if I have more questions about ...
# Evaluating responses for question: What is the difference between CSD and DAI?...
# Evaluating responses for question: Can you tell me about the admission process?...
# Evaluating responses for question: How can I prepare for the admission process?...
# Evaluating responses for question: What is the meaning of pillar?...
#
# Question: What are the admissions deadlines for SUTD?
#
# Base Model (No RAG):
# Accuracy: 3, Relevant: 4, Grounded: 2
# Comments: The response provides the accurate application deadline for SUTD, which is a factual piece of information. It is relevant to the question asked. However, the response lacks grounding as it does not provide any specific details or sources to support the deadline information. It could be improved by including more context or details about the admissions process at SUTD.
#
# Finetuned Model (No RAG):
# Accuracy: 4, Relevant: 5, Grounded: 3
# Comments: The response provides accurate information regarding the admissions deadlines for international and domestic applicants at SUTD. It directly addresses the question asked, making it highly relevant. However, the response lacks specific details or sources to support the information provided. The retrieved documents do not contain exact matching text for the admissions deadlines, so the response could have been more grounded with additional specific details or sources.
#
# Base Model with RAG):
# Accuracy: 3, Relevant: 3, Grounded: 2
# Comments: The response provides some information about admissions deadlines for SUTD, which is partially accurate. However, it lacks specific details such as the exact deadlines or any reference to the retrieved documents. The response is somewhat relevant to the question but could be more focused on providing concrete information. It is not well-grounded as it does not align closely with the retrieved documents, lacking specific details or sources to support the information provided.
#
# Finetuned Model with RAG):
# Accuracy: 2, Relevant: 3, Grounded: 2
# Comments: The response does not directly answer the question about the admissions deadlines for SUTD. While it mentions the admissions process and criteria, it fails to provide specific information on the deadlines. The response is somewhat relevant as it discusses the admissions process, but it lacks the specific details requested. The grounding is low as it does not reference or provide specific information from the retrieved documents related to admissions deadlines.
#
# ================================================================================
#
#
# Question: Is there financial aid available?
#
# Base Model (No RAG):
# Accuracy: 4, Relevant: 5, Grounded: 4
# Comments: The response accurately confirms that there is financial aid available at SUTD and provides specific details about the types of scholarships offered. It is highly relevant to the question asked and directly addresses the inquiry about financial aid options. The response is grounded in the context provided from the retrieved documents, aligning with the information about scholarships and financial aid available at SUTD.
#
# Finetuned Model (No RAG):
# Accuracy: 4, Relevant: 5, Grounded: 3
# Comments: The response accurately states that SUTD offers scholarships and bursaries for financial aid, which is factually correct. It is highly relevant to the question asked. However, the response lacks specific details or sources to support the information provided, which lowers the grounded score. The response could have been improved by including specific examples of scholarships offered or linking to relevant pages on the SUTD website for more information.
#
# Base Model with RAG):
# Accuracy: 3, Relevant: 4, Grounded: 2
# Comments: The response provides information about the types of scholarships available at SUTD, which is somewhat accurate and relevant to the question. However, it lacks specific details or sources to support the information provided, resulting in a lower score for being grounded. The response could be improved by including specific examples of scholarships available at SUTD and citing relevant sources to enhance credibility.
#
# Finetuned Model with RAG):
# Accuracy: 4, Relevant: 5, Grounded: 3
# Comments: The response provides accurate information about the availability of financial aid at SUTD, mentioning study loans, grants, and scholarships. It directly addresses the question asked, making it highly relevant. However, the response lacks specific details or sources to support the information provided, which could enhance its credibility and depth.
#
# ================================================================================
#
#
# Question: What is the minimum score for the Mother Tongue Language?
#
# Base Model (No RAG):
# Accuracy: 2, Relevant: 3, Grounded: 2
# Comments: The response provides some information about the mother tongue language test but does not directly answer the question about the minimum score required. The mention of English as a second language is somewhat relevant but does not address the specific numerical score required. The response lacks specific details or sources to support the information provided, resulting in a low grounded score. It does not align well with the retrieved documents which do not mention the minimum score for the Mother Tongue Language test.
#
# Finetuned Model (No RAG):
# Accuracy: 2, Relevant: 3, Grounded: 2
# Comments: The response provides some information about the minimum score required for Mother Tongue Language at SUTD, but it inaccurately mentions tests like IELTS, TOEFL, and PTE Academic which are typically for English proficiency, not Mother Tongue Language. The response is somewhat relevant as it attempts to address the question but misses the mark by focusing on English language proficiency tests. The grounding is low as the information provided does not align with the context from the retrieved documents, which specifically mention Mother Tongue Language requirements for Singapore citizens and permanent residents.
#
# Base Model with RAG):
# Accuracy: 2, Relevant: 3, Grounded: 2
# Comments: The response provided is partially accurate as it mentions some languages that are considered mother tongue languages, but it does not give the minimum score required for the Mother Tongue Language. The relevance is somewhat low as it does not directly answer the question. The grounding is also low as the response does not align well with the context from the retrieved documents.
#
# Finetuned Model with RAG):
# Accuracy: 4, Relevant: 3, Grounded: 2
# Comments: The response provides a general understanding of how the minimum score for Mother Tongue Language may vary based on proficiency levels, which is mostly accurate. However, it lacks specific information about the actual minimum scores required at SUTD. The response is somewhat relevant as it addresses the concept of varying minimum scores but does not directly answer the question about the specific minimum score for Mother Tongue Language at SUTD. The grounding is low as it does not reference any specific details or sources related to the minimum score requirements at SUTD.
#
# ================================================================================
#
#
# Question: Do I require reference letters?
#
# Base Model (No RAG):
# Accuracy: 3, Relevant: 4, Grounded: 2
# Comments: The response is somewhat accurate in stating that reference letters are required, which aligns with the context provided. It is relevant to the question asked. However, the response lacks grounding as it does not provide specific details or sources related to SUTD's requirements for reference letters. It could have been more informative and detailed to improve its grounded score.
#
# Finetuned Model (No RAG):
# Accuracy: 3, Relevant: 4, Grounded: 2
# Comments: The response inaccurately states that international students do not need references to apply at SUTD University, which contradicts the retrieved documents that mention the need for appropriate citation and discussion facilitation. While the response is somewhat relevant as it addresses the application process for international students, it lacks grounding as it does not align with the information retrieved from the documents. It would have been more grounded if it had mentioned the need for references or at least acknowledged the requirement mentioned in the documents.
#
# Base Model with RAG):
# Accuracy: 4, Relevant: 5, Grounded: 3
# Comments: The response is mostly accurate as it correctly states that reference letters are not required when applying through the OSA online system at SUTD. It is highly relevant to the question asked. However, the response lacks grounding as it does not directly align with the retrieved document content provided, which discusses research personnel providing appropriate citation for text, data, or figures from other publications or sources.
#
# Finetuned Model with RAG):
# Accuracy: 3, Relevant: 4, Grounded: 3
# Comments: The response is somewhat accurate as it mentions the necessity of reference letters for applications, which is generally true. It is relevant to the question asked. However, the response lacks specific details or sources to support the information provided. It could have been more grounded by referencing specific policies or guidelines related to reference letters at SUTD.
#
# ================================================================================
#
#
# Question: Can polytechnic diploma students apply?
#
# Base Model (No RAG):
# Accuracy: 2, Relevant: 3, Grounded: 2
# Comments: The response is partially accurate as it states that Polytechnic Diploma holders can be admitted to all courses offered at NUS, which is not relevant to the question about SUTD. The response is somewhat relevant as it addresses the admission of diploma holders but fails to focus on SUTD specifically. It is not well-grounded as it does not provide specific details or sources related to SUTD's admission policies for Polytechnic Diploma students. The response lacks direct relevance to the question asked and does not align well with the retrieved documents related to SUTD.
#
# Finetuned Model (No RAG):
# Accuracy: 4, Relevant: 5, Grounded: 4
# Comments: The response is mostly accurate in stating that polytechnic diploma students can apply to universities, including SUTD, based on the retrieved documents. It is highly relevant to the question asked. The response is grounded as it aligns with the information provided in the context, which mentions that applicants with diplomas from specific institutions can apply. However, providing more specific details or examples could further enhance the grounded score.
#
# Base Model with RAG):
# Accuracy: 2, Relevant: 3, Grounded: 2
# Comments: The response does not directly address the question about polytechnic diploma students applying to SUTD. While it provides some information about application requirements and prerequisites, it does not specifically mention polytechnic diploma students. The response lacks grounding in the context provided from the retrieved documents, as it does not align well with the information presented. It would be more helpful to directly address the question about polytechnic diploma students and their eligibility for application to SUTD.
#
# Finetuned Model with RAG):
# Accuracy: 3, Relevant: 4, Grounded: 2
# Comments: The response is somewhat accurate in stating that polytechnic diploma students can apply to SUTD. It is relevant as it directly answers the question. However, the response lacks grounding as it does not provide specific details or sources to support the information given. It could have been improved by referencing specific admission criteria or policies related to polytechnic diploma students applying to SUTD.
#
# ================================================================================
#
#
# Question: Do I need SAT score?
#
# Base Model (No RAG):
# Accuracy: 1, Relevant: 2, Grounded: 1
# Comments: The response provided is inaccurate as it states that no test is required before applying to SUTD, which is not true based on the retrieved documents. The response is somewhat relevant as it talks about the application process but does not directly address the question about SAT scores. It is not grounded as it does not align with the information retrieved from the documents, which clearly mention the optional nature of SAT scores for application.
#
# Finetuned Model (No RAG):
# Accuracy: 4, Relevant: 5, Grounded: 3
# Comments: The response is mostly accurate as it correctly states that the SAT score is not mandatory for admission to SUTD if high school grades meet the requirements. It is highly relevant to the question asked. However, the response lacks grounding as it does not directly reference or quote from the retrieved documents to support the information provided. It would have been more grounded if it had included specific details or quotes from the documents to back up the statement about SAT scores not being required for admission.
#
# Base Model with RAG):
# Accuracy: 3, Relevant: 2, Grounded: 1
# Comments: The response is not entirely accurate as it does not directly address whether an SAT score is required for SUTD. It is somewhat relevant as it mentions the strong interest in the SUTD experience but does not directly answer the question. The response lacks grounding in specific details or sources related to SAT score requirements at SUTD.
#
# Finetuned Model with RAG):
# Accuracy: 1, Relevant: 1, Grounded: 1
# Comments: The response provided is inaccurate as per the retrieved documents, which clearly state that SAT scores are optional for application to SUTD. The answer is not relevant to the question asked and lacks grounding in the provided context. It does not align with the factual information available.
#
# ================================================================================
#
#
# Question: How many PhD students does SUTD have?
#
# Base Model (No RAG):
# Accuracy: 1, Relevant: 1, Grounded: 1
# Comments: The response provided, "3," is completely inaccurate and does not align with the context from the retrieved documents. It does not address the question about the number of PhD students at SUTD at all. The answer lacks any grounding in the information available and does not make use of the provided context to derive a meaningful response.
#
# Finetuned Model (No RAG):
# Accuracy: 2, Relevant: 3, Grounded: 1
# Comments: The response provided is not accurate as it states that SUTD has only 3 PhD candidates enrolled, which is not a realistic number for a university. It is somewhat relevant to the question but lacks specific details or sources to support the claim. The response is not grounded in the retrieved documents as it does not align with the typical number of PhD students in a university setting.
#
# Base Model with RAG):
# Accuracy: 2, Relevant: 3, Grounded: 2
# Comments: The response provides a specific number for the current enrollment of PhD students at SUTD, which is somewhat accurate. However, it does not directly answer the question of how many PhD students SUTD has in total. The response lacks grounding as it does not align well with the context from the retrieved documents, which do not mention the exact number of PhD students at SUTD.
#
# Finetuned Model with RAG):
# Accuracy: 1, Relevant: 1, Grounded: 1
# Comments: The response provided is completely irrelevant and does not answer the question about the number of PhD students at SUTD. It seems to be a copy-paste error or a technical issue as it does not contain any information related to the query. This response lacks accuracy, relevance, and grounding in the context of the retrieved documents.
#
# ================================================================================
#
#
# Question: How much are the tuition fees for Singaporeans?
#
# Base Model (No RAG):
# Accuracy: 1, Relevant: 1, Grounded: 1
# Comments: The response provided is completely inaccurate, irrelevant, and not grounded in any factual information related to the question about tuition fees for Singaporeans at SUTD. The response seems to be a random text fragment unrelated to the query. It does not address the question at all and does not provide any meaningful information regarding tuition fees.
#
# Finetuned Model (No RAG):
# Accuracy: 4, Relevant: 5, Grounded: 3
# Comments: The response provides accurate information about the tuition fees for Singapore citizens at SUTD, which is commendable. It directly addresses the question asked, making it highly relevant. However, the response lacks grounding as it does not reference or align with the specific details retrieved from the documents. Including specific details or sources related to the tuition fees would have improved the grounding score.
#
# Base Model with RAG):
# Accuracy: 2, Relevant: 3, Grounded: 2
# Comments: The response provides a general range of estimated costs related to attending SUTD, but it does not specifically address the question about tuition fees for Singaporeans. The information provided seems to be more focused on the overall cost of attendance rather than just tuition fees. Additionally, the response lacks specific details or sources to support the provided cost estimates. It would have been more accurate and grounded if it directly addressed the tuition fees for Singaporeans at SUTD and provided specific information or sources to support the answer.
#
# Finetuned Model with RAG):
# Accuracy: 4, Relevant: 5, Grounded: 3
# Comments: The response provides a fairly accurate range for the tuition fees for Singaporeans at SUTD, although it could have been more precise by mentioning the exact figures or specifying the subject areas that fall within this range. The answer is highly relevant as it directly addresses the question asked. However, it lacks grounding as it does not directly align with the specific details retrieved from the documents, such as the mention of tuition fee loans and scholarships.
#
# ================================================================================
#
#
# Question: How much are the tuition fees for international students?
#
# Base Model (No RAG):
# Accuracy: 4, Relevant: 5, Grounded: 3
# Comments: The response accurately provides the tuition fee for undergraduate international students at SUTD, which is $35,000 per year. It is highly relevant to the question asked. However, the response lacks grounding as it does not directly reference the specific details mentioned in the retrieved documents regarding tuition fees for international students, which could have further supported the response.
#
# Finetuned Model (No RAG):
# Accuracy: 4, Relevant: 5, Grounded: 3
# Comments: The response provides accurate information about the tuition fees for international students at SUTD, which is commendable. It directly addresses the question asked, making it highly relevant. However, the response lacks grounding as it does not align with the specific details retrieved from the documents. The mentioned tuition fee of 40,000 SGD per year does not match the information found in the retrieved text, which could lead to confusion for users seeking precise details.
#
# Base Model with RAG):
# Accuracy: 1, Relevant: 1, Grounded: 1
# Comments: The response provided is highly inaccurate, irrelevant, and not grounded in any factual information related to SUTD or the question asked. It simply assumes a random figure without any basis or connection to the actual tuition fees for international students at SUTD. This response does not align with the context from the retrieved documents and fails to address the question effectively.
#
# Finetuned Model with RAG):
# Accuracy: 2, Relevant: 3, Grounded: 2
# Comments: The response provides some information about the tuition fees for international students at SUTD, but it does not directly answer the question about the specific amount of tuition fees. The mention of a range between SGD13,000 - SGD15,500 annually is somewhat accurate but lacks precision. The response could have been more specific and directly addressed the question. Additionally, the response is not well-grounded as it does not align closely with the retrieved documents, which do not provide the exact tuition fees for international students at SUTD.
#
# ================================================================================
#
#
# Question: Is there a minimum CAP?
#
# Base Model (No RAG):
# Accuracy: 1, Relevant: 1, Grounded: 1
# Comments: The response provided, "Yes, it is 10 points," is factually incorrect and does not align with the context from the retrieved documents. The answer does not address the question about the minimum CAP accurately or provide any relevant information. It lacks grounding in any specific details or sources related to the minimum CAP requirement at SUTD.
#
# Finetuned Model (No RAG):
# Accuracy: 4, Relevant: 5, Grounded: 3
# Comments: The response accurately states that there is no minimum CAP requirement for SUTD admissions, which aligns with the retrieved documents. It is highly relevant to the question asked. However, the response lacks specific details or sources to support the information provided, which lowers the grounded score.
#
# Base Model with RAG):
# Accuracy: 2, Relevant: 1, Grounded: 2
# Comments: The response provided is not accurate in addressing the question about the minimum CAP at SUTD. It includes unrelated information about cost calculations and competition between companies, which is not relevant to the question asked. The response lacks grounding in the context of the retrieved documents, as it does not directly address the query about the minimum CAP requirement at SUTD.
#
# Finetuned Model with RAG):
# Accuracy: 4, Relevant: 5, Grounded: 3
# Comments: The response is mostly accurate as it correctly states that there is no minimum CAP at SUTD and that it depends on individual circumstances and academic performance. It is highly relevant to the question asked. However, the response lacks grounding in the retrieved documents as it does not directly reference or align with the information provided.
#
# ================================================================================
#
#
# Question: What is the difference between CSD in SUTD and Computer Science major in nus?
#
# Base Model (No RAG):
# Accuracy: 4, Relevant: 5, Grounded: 3
# Comments: The response provides accurate information about the differences between the CSD program at SUTD and Computer Science majors in general, highlighting the practical experience aspect of CSD and the rigorous mathematics courses in Computer Science. The answer is highly relevant to the question asked. However, the response lacks specific details or sources to support the claims made about the programs, which lowers the grounded score. It aligns with the general context of the retrieved documents but could benefit from more specific references or examples to enhance credibility.
#
# Finetuned Model (No RAG):
# Accuracy: 4, Relevant: 5, Grounded: 3
# Comments: The response provides accurate information about the differences between the CSD program at SUTD and the Computer Science program at NUS. It directly addresses the question and is relevant by comparing the specific focus areas of each program. However, the response lacks specific details or sources to support the information provided, which lowers the grounded score.
#
# Base Model with RAG):
# Accuracy: 2, Relevant: 1, Grounded: 1
# Comments: The response provided is not accurate as it does not address the question about the difference between the CSD program at SUTD and the Computer Science major at NUS. It is not relevant at all as it redirects the user to apply online and talks about programming languages without addressing the core question. The response lacks grounding in the retrieved documents as it does not align with the content provided.
#
# Finetuned Model with RAG):
# Accuracy: 4, Relevant: 5, Grounded: 3
# Comments: The response provides a fairly accurate comparison between the CSD program at SUTD and the Computer Science major at NUS. It correctly highlights the differences in focus between the two programs. The answer is highly relevant to the question asked. However, the response lacks specific details or sources to support the comparison, which lowers its grounded score. It would benefit from referencing specific program details or sources to further strengthen its groundedness.
#
# ================================================================================
#
#
# Question: What is the teaching style like in SUTD?
#
# Base Model (No RAG):
# Accuracy: 2, Relevant: 3, Grounded: 1
# Comments: The response does not directly address the question about the teaching style at SUTD. It goes off on a tangent about the educator's learning journey and the multidisciplinary education approach at SUTD, which is somewhat related but not a direct answer. The response lacks specific details or examples related to the teaching style at SUTD, making it vague and unsupported. It does not align well with the retrieved documents which focus more on academic and research aspects rather than teaching methodologies.
#
# Finetuned Model (No RAG):
# Accuracy: 2, Relevant: 3, Grounded: 1
# Comments: The response lacks accuracy as it does not provide specific details about the teaching style at SUTD. While it mentions some general aspects like hands-on learning and student support services, it does not delve into the specific teaching methodologies or approaches used at SUTD. The response is somewhat relevant as it touches on aspects related to teaching, but it does not directly address the question about the teaching style at SUTD. The response is not grounded in the retrieved documents as it does not align with the specific information provided in the context.
#
# Base Model with RAG):
# Accuracy: 2, Relevant: 3, Grounded: 1
# Comments: The response lacks accuracy as it does not provide specific information about the teaching style at SUTD. While it mentions various teaching methods, it does not directly address the question about the teaching style at SUTD. The response is somewhat relevant as it discusses teaching methods, but it does not focus on the specific teaching style at SUTD. Additionally, the response is not grounded in the retrieved documents as it does not align with the specific details or terminology found in the documents related to SUTD's teaching style.
#
# Finetuned Model with RAG):
# Accuracy: 2, Relevant: 4, Grounded: 2
# Comments: The response provides a general overview of the teaching styles at SUTD, which is somewhat relevant to the question. However, it lacks specific details or examples that could have made it more accurate and grounded. The response could have been improved by referencing specific teaching methodologies or approaches used at SUTD, as found in the retrieved documents.
#
# ================================================================================
#
#
# Question: What are the possible career path for ESD pillar?
#
# Base Model (No RAG):
# Accuracy: 2, Relevant: 3, Grounded: 1
# Comments: The response does not provide specific information about the possible career paths for the ESD pillar at SUTD. While it mentions general fields like engineering design, mechanical engineering, electrical & electronics, and computer science & software development, it lacks depth and specificity. The response could have been improved by providing examples of actual job roles or industries where ESD graduates typically find employment within the context of SUTD's ESD pillar. Additionally, the response does not align well with the retrieved documents, as it does not offer detailed insights or specific career paths related to the ESD pillar as mentioned in the documents.
#
# Finetuned Model (No RAG):
# Accuracy: 3, Relevant: 4, Grounded: 2
# Comments: The response provides a general overview of possible career paths for ESD pillar students, which is somewhat accurate and relevant to the question. However, it lacks specific details or examples to support the mentioned career paths. The response could be improved by including more specific information about the types of roles ESD graduates typically pursue and how the ESD pillar at SUTD prepares students for these careers.
#
# Base Model with RAG):
# Accuracy: 3, Relevant: 4, Grounded: 2
# Comments: The response provides possible career paths for the ESD pillar, which is relevant to the question. However, the answer lacks specific details or sources to support the mentioned career paths. The response could be improved by providing more specific examples or linking the information to the retrieved documents for better grounding.
#
# Finetuned Model with RAG):
# Accuracy: 3, Relevant: 4, Grounded: 2
# Comments: The response provides a general overview of possible career paths for ESD pillar graduates, mentioning fields like software development, cybersecurity, robotics, AI, machine learning, and entrepreneurship. While the answer is somewhat relevant to the question, it lacks specific details or examples to support the claims made. The response could be improved by providing more concrete examples or linking these career paths directly to the ESD pillar at SUTD.
#
# ================================================================================
#
#
# Question: How heavy are the project workload like in SUTD?
#
# Base Model (No RAG):
# Accuracy: 1, Relevant: 1, Grounded: 1
# Comments: The response provided is not accurate, relevant, or grounded in any way to the question asked about the project workload at SUTD. The answer seems to be a random excerpt from a document that does not address the question at all. It does not provide any meaningful information about the workload of projects at SUTD.
#
# Finetuned Model (No RAG):
# Accuracy: 2, Relevant: 4, Grounded: 3
# Comments: The response does not directly address the question about the heaviness of project workload at SUTD. While it provides information about the nature and purpose of projects at SUTD, it does not quantify or describe the actual workload intensity. The response is relevant in the sense that it discusses projects at SUTD, but it lacks specificity in directly addressing the workload aspect. The grounding is somewhat weak as the response does not provide concrete details or examples to support the claims made about project workload at SUTD.
#
# Base Model with RAG):
# Accuracy: 3, Relevant: 4, Grounded: 2
# Comments: The response provides some information about the project workload at SUTD, mentioning the average hours per week for first-year and second-year undergraduates. However, it lacks specific details or sources to support these claims. The response could be improved by providing more concrete examples or referencing official documentation to support the information provided.
#
# Finetuned Model with RAG):
# Accuracy: 3, Relevant: 3, Grounded: 2
# Comments: The response does not directly address the question about the project workload at SUTD. While it mentions aspects of critical thinking and problem-solving skills in engineering projects, it does not provide specific information on the heaviness of the workload. The response lacks grounding as it does not draw from the retrieved documents to support the information provided. It could be improved by including specific details or statistics related to project workload at SUTD.
#
# ================================================================================
#
#
# Question: How does the employment rates of SUTD compare to other universities like NUS and NTU?
#
# Base Model (No RAG):
# Accuracy: 2, Relevant: 3, Grounded: 2
# Comments: The response lacks accuracy as it does not provide any specific information about the employment rates of SUTD compared to NUS and NTU. It is somewhat relevant as it suggests looking into research for the comparison, but it does not directly address the question. The grounding is low as it does not provide any specific details or sources related to the employment rates comparison. The retrieved document does not provide relevant information to support the response.
#
# Finetuned Model (No RAG):
# Accuracy: 4, Relevant: 5, Grounded: 3
# Comments: The response provides accurate information about the high placement success rate of SUTD graduates, which is supported by the retrieved document mentioning a 90% placement rate. The answer is highly relevant to the question asked about comparing employment rates between SUTD and other universities like NUS and NTU. However, the response lacks specific details or sources to support the claim of SUTD's high placement success rate compared to NUS and NTU. It would have been more grounded if it included comparative data or references to support the statement.
#
# Base Model with RAG):
# Accuracy: 2, Relevant: 3, Grounded: 2
# Comments: The response acknowledges the lack of specific data comparing employment rates between SUTD, NUS, and NTU, which is accurate. However, it does not provide any further context or information related to the question. The response could have been more grounded by mentioning general trends or information about employment rates in universities in Singapore, even if specific data for comparison is not available.
#
# Finetuned Model with RAG):
# Accuracy: 2, Relevant: 4, Grounded: 2
# Comments: The response does not directly answer the question about comparing employment rates between SUTD, NUS, and NTU. While it mentions SUTD's support systems and collaborations with industry partners, it lacks specific data or comparisons with NUS and NTU. The response is somewhat relevant as it discusses factors that could influence employability but does not address the comparison directly. The lack of specific data or statistics from the retrieved documents impacts the grounded score.
#
# ================================================================================
#
#
# Question: Who can I approach if I have more questions about SUTD?
#
# Base Model (No RAG):
# Accuracy: 1, Relevant: 1, Grounded: 1
# Comments: This response is inaccurate, irrelevant, and not grounded in any specific information related to the question about who to approach for more questions about SUTD. The response provided is a generic message that does not address the question at all. It lacks any factual correctness or specific details related to SUTD's support services or personnel who can assist with inquiries.
#
# Finetuned Model (No RAG):
# Accuracy: 3, Relevant: 4, Grounded: 2
# Comments: The response is somewhat accurate in providing a general direction for the student to seek more information from the Admissions team. It is relevant to the question asked as it addresses who to approach for more questions about SUTD. However, it lacks grounding as it does not directly align with the retrieved documents which were more about academic opportunities and news at SUTD. A more specific reference to the documents could have improved the grounding score.
#
# Base Model with RAG):
# Accuracy: 3, Relevant: 4, Grounded: 2
# Comments: The response provides accurate contact information for Student Ambassadors at SUTD, which is relevant to the question asked. However, the response lacks grounding as it does not directly address the question about who to approach for more general questions about SUTD. The retrieved documents do not contain specific information about who to contact for general inquiries, so the response could have been more grounded by providing information based on official sources or documentation.
#
# Finetuned Model with RAG):
# Accuracy: 3, Relevant: 4, Grounded: 2
# Comments: The response provides accurate information on where to find more details about SUTD and who to contact for inquiries, which is a common query. It is relevant as it directly addresses the question asked. However, the response lacks grounding as it does not directly align with the retrieved documents. The response could have been more grounded by referencing specific contact information or support services mentioned in the documents.
#
# ================================================================================
#
#
# Question: What is the difference between CSD and DAI?
#
# Base Model (No RAG):
# Accuracy: 2, Relevant: 1, Grounded: 2
# Comments: The response provided is inaccurate as it does not address the difference between CSD and DAI at SUTD. It is also not relevant to the question asked, as it diverts the topic to CAD and CAS, which are not the subjects of the inquiry. The response lacks grounding as it does not align with the context from the retrieved documents, failing to provide specific details or sources related to the actual comparison between CSD and DAI at SUTD.
#
# Finetuned Model (No RAG):
# Accuracy: 4, Relevant: 5, Grounded: 3
# Comments: The response provides accurate information about the differences between the CSD and DAI programs at SUTD, focusing on specialization, design thinking, real-world applications, research opportunities, hands-on experience, industry connections, and interdisciplinary collaboration. It is highly relevant to the question asked. However, the response lacks specific details or sources to support the information provided, which lowers the grounded score.
#
# Base Model with RAG):
# Accuracy: 4, Relevant: 4, Grounded: 2
# Comments: The response provides a general idea of the differences between CSD and DAI, focusing on student involvement in industry-related activities and the value for graduates. While the information provided is accurate and relevant to the question, it lacks specific details or sources to support the claims made. The response could be improved by referencing specific aspects of the CSD and DAI programs at SUTD to provide a more grounded comparison.
#
# Finetuned Model with RAG):
# Accuracy: 4, Relevant: 5, Grounded: 3
# Comments: The response provides a good overview of the differences between the CSD and DAI programs at SUTD. It accurately highlights the key distinctions in emphasis on traditional programming skills and design principles for CSD, and artificial intelligence and practical applications for DAI. The response is highly relevant to the question asked. However, the grounding could be improved by providing more specific examples or references from the retrieved documents to support the comparison between the two programs.
#
# ================================================================================
#
#
# Question: Can you tell me about the admission process?
#
# Base Model (No RAG):
# Accuracy: 2, Relevant: 3, Grounded: 1
# Comments: The response does not directly answer the question about the admission process at SUTD. It mentions the application deadline but does not provide information on the actual steps or requirements for admission. The answer is somewhat relevant as it touches on the application deadline, but it lacks specificity and details related to the admission process at SUTD. The response is not grounded in the retrieved documents as it does not provide any specific information or details related to the admission process as mentioned in the context.
#
# Finetuned Model (No RAG):
# Accuracy: 2, Relevant: 3, Grounded: 2
# Comments: The response does not directly address the admission process at SUTD, providing generic information about the admissions office's goals and support services. While it vaguely mentions personalized guidance and support services, it lacks specific details about the actual admission process at SUTD. The response is somewhat relevant as it touches on aspects related to admissions but does not provide concrete information. Additionally, it is not grounded as it does not align well with the context from the retrieved documents regarding admission criteria and timelines.
#
# Base Model with RAG):
# Accuracy: 2, Relevant: 1, Grounded: 1
# Comments: The response provided is not accurate as it does not directly address the question about the admission process at SUTD. It is also not relevant as it goes off on a tangent discussing international undergraduate programs and their commencement dates. Additionally, the response lacks grounding as it does not align with the context from the retrieved documents which are related to admission criteria and timelines.
#
# Finetuned Model with RAG):
# Accuracy: 2, Relevant: 2, Grounded: 1
# Comments: The response provided is not accurate as it does not address the specific admission process at SUTD. It is somewhat relevant as it mentions the selection process and eligibility criteria, but it lacks specific details that would make it more relevant. The response is not grounded in the retrieved documents as it does not align with the information provided in the context. It lacks specific information about the admission process at SUTD, which is crucial for a comprehensive answer.
#
# ================================================================================
#
#
# Question: How can I prepare for the admission process?
#
# Base Model (No RAG):
# Accuracy: 2, Relevant: 3, Grounded: 1
# Comments: The response provides general tips on preparing for the admission process, but it lacks specific information related to the SUTD admission process. It does not directly address the question about preparing for the admission process at SUTD. The response is not grounded in the context from the retrieved documents, as it does not align with the specific details or guidance provided in the documents.
#
# Finetuned Model (No RAG):
# Accuracy: 4, Relevant: 5, Grounded: 3
# Comments: The response provides accurate and relevant tips on preparing for the admissions process at SUTD. It covers various steps such as researching courses, applying early, submitting portfolios, taking mock interviews, and attending events. While the information is relevant and aligns with general admission preparation advice, it lacks specific details or sources from the retrieved documents to further support the suggestions provided.
#
# Base Model with RAG):
# Accuracy: 3, Relevant: 4, Grounded: 2
# Comments: The response provides some general tips on how to prepare for the admission process at SUTD, which are somewhat relevant to the question. However, the response lacks specific details or references to the SUTD admission process itself. It does not directly address the specific steps or requirements for SUTD admission, leading to a lower grounded score. More specific and accurate information related to the SUTD admission process would have improved the overall score.
#
# Finetuned Model with RAG):
# Accuracy: 4, Relevant: 4, Grounded: 2
# Comments: The response provides generally accurate advice on preparing for the admission process at SUTD, focusing on Mathematics and Sciences alignment with SUTD's values and showcasing strengths. It also mentions attending relevant courses or workshops to enhance readiness, which is relevant to the question. However, the response lacks specific details or sources to support the advice given, making it less grounded compared to the retrieved documents. It could benefit from referencing specific admission requirements or strategies outlined in official SUTD documentation to enhance its credibility.
#
# ================================================================================
#
#
# Question: What is the meaning of pillar?
#
# Base Model (No RAG):
# Accuracy: 2, Relevant: 3, Grounded: 1
# Comments: The response provided is not accurate in the context of the question about the meaning of "pillar" in the context of SUTD. The answer talks about the general meaning of a pillar as a supporting structure like a column, which is not relevant to the specific context of SUTD's pillars. It lacks grounding in the retrieved documents which clearly pertain to SUTD's academic pillars and their focus areas. The response should have focused on explaining the specific meaning of "pillar" within the academic structure of SUTD.
#
# Finetuned Model (No RAG):
# Accuracy: 2, Relevant: 1, Grounded: 1
# Comments: The response provided is not accurate as it does not address the actual meaning of "pillar" within the context of SUTD. It is not relevant to the question asked as it focuses on personal development rather than the academic structure of SUTD. Additionally, the response lacks grounding in the retrieved documents as it does not align with the information provided.
#
# Base Model with RAG):
# Accuracy: 1, Relevant: 1, Grounded: 1
# Comments: The response provided is completely inaccurate and irrelevant to the question asked about the meaning of "pillar." It seems to be a random excerpt from a document that does not address the context of the question at all. There is no connection between the retrieved text and the actual meaning of "pillar" in the context of SUTD.
#
# Finetuned Model with RAG):
# Accuracy: 4, Relevant: 5, Grounded: 3
# Comments: The response accurately describes the ISTD pillar at SUTD and its focus on Information Technology Science & Engineering. It is highly relevant to the question asked. However, the response lacks grounding as it does not directly reference or align with the specific details provided in the retrieved documents. It would benefit from incorporating more specific details or verbatim content from the documents to improve its grounding.
#
# ================================================================================

# %% [markdown]
# # Bonus points: chatbot UI (RIO)
#
# Implement a web UI frontend for your chatbot that you can demo in class.

# %%
# QUESTION: Implement a web UI frontend for your chatbot that you can demo in class.
# !pip install --upgrade gradio
import gradio as gr
import pandas as pd
import time

responses = []
show_evaluations = False

def toggle_evaluations():
    global show_evaluations
    show_evaluations = not show_evaluations
    return "LLM Judge Ratings: " + ("ON" if show_evaluations else "OFF")

def get_answers(question):
    global responses, show_evaluations

    if not question:
        return "", "", "", "", "Please enter a question."

    try:
        progress = gr.Progress(track_tqdm=True)
        progress.update(0.1)  # Just update percentage (no desc)

        # Generate responses
        base_no_rag = generate_base_no_rag(question)
        finetuned_no_rag = generate_finetuned_no_rag(question)
        base_with_rag, base_docs = generate_base_with_rag(question)
        finetuned_with_rag, finetuned_docs = generate_finetuned_with_rag(question)

        eval_base_no_rag = eval_finetuned_no_rag = eval_base_with_rag = eval_finetuned_with_rag = None

        if show_evaluations:
            progress.update(0.5)  # Midpoint update
            eval_base_no_rag = evaluate_response(question, base_no_rag, [])
            time.sleep(1)
            eval_finetuned_no_rag = evaluate_response(question, finetuned_no_rag, [])
            time.sleep(1)
            eval_base_with_rag = evaluate_response(question, base_with_rag, [doc.page_content for doc in base_docs])
            time.sleep(1)
            eval_finetuned_with_rag = evaluate_response(question, finetuned_with_rag, [doc.page_content for doc in finetuned_docs])

        # Save and return formatted response
        responses.insert(0, {
            "question": question,
            "base_no_rag": base_no_rag,
            "finetuned_no_rag": finetuned_no_rag,
            "base_with_rag": base_with_rag,
            "finetuned_with_rag": finetuned_with_rag,
            "docs": [doc.page_content for doc in base_docs],
            "evals": {
                "base_no_rag": eval_base_no_rag,
                "finetuned_no_rag": eval_finetuned_no_rag,
                "base_with_rag": eval_base_with_rag,
                "finetuned_with_rag": eval_finetuned_with_rag,
            }
        })

        progress.update(1.0)  # Done
        return format_response(responses[0])

    except Exception as e:
        print("❌ Error in get_answers:", e)
        return "Error", "Error", "Error", "Error", f"Error: {str(e)}"


def format_response(response):
    base_no_rag = response['base_no_rag']
    finetuned_no_rag = response['finetuned_no_rag']
    base_with_rag = response['base_with_rag']
    finetuned_with_rag = response['finetuned_with_rag']
    docs = response['docs']

    if show_evaluations and response['evals']['base_no_rag']:
        eval = response['evals']['base_no_rag']
        base_no_rag += f"\n\n**Evaluation:** Accuracy: {eval['Accuracy']}/5 | Relevant: {eval['Relevant']}/5 | Grounded: {eval['Grounded']}/5\nComments: {eval['Comments']}"

    if show_evaluations and response['evals']['finetuned_no_rag']:
        eval = response['evals']['finetuned_no_rag']
        finetuned_no_rag += f"\n\n**Evaluation:** Accuracy: {eval['Accuracy']}/5 | Relevant: {eval['Relevant']}/5 | Grounded: {eval['Grounded']}/5\nComments: {eval['Comments']}"

    if show_evaluations and response['evals']['base_with_rag']:
        eval = response['evals']['base_with_rag']
        base_with_rag += f"\n\n**Evaluation:** Accuracy: {eval['Accuracy']}/5 | Relevant: {eval['Relevant']}/5 | Grounded: {eval['Grounded']}/5\nComments: {eval['Comments']}"

    if show_evaluations and response['evals']['finetuned_with_rag']:
        eval = response['evals']['finetuned_with_rag']
        finetuned_with_rag += f"\n\n**Evaluation:** Accuracy: {eval['Accuracy']}/5 | Relevant: {eval['Relevant']}/5 | Grounded: {eval['Grounded']}/5\nComments: {eval['Comments']}"

    docs_text = "\n\n".join([f"Document {i+1}: {doc[:200]}..." if len(doc) > 200 else f"Document {i+1}: {doc}"
                            for i, doc in enumerate(docs)])

    return base_no_rag, finetuned_no_rag, base_with_rag, finetuned_with_rag, docs_text

with gr.Blocks(title="SUTD Chatbot Comparison") as demo:
    gr.Markdown("# SUTD Chatbot System Comparison")
    gr.Markdown("Compare responses from 4 different model configurations")

    with gr.Row():
        question = gr.Textbox(label="Enter your question about SUTD:",
                            placeholder="e.g. What are the admissions deadlines for SUTD?")
        submit_btn = gr.Button("Get Answers")

    toggle_btn = gr.Button("Toggle LLM Judge Ratings")
    eval_status = gr.Textbox(label="Evaluation Status", value="LLM Judge Ratings: OFF", interactive=False)

    with gr.Row():
        with gr.Column():
            gr.Markdown("### Base Model (No RAG)")
            base_no_rag = gr.Textbox(label="", lines=5, interactive=False)
        with gr.Column():
            gr.Markdown("### Finetuned Model (No RAG)")
            finetuned_no_rag = gr.Textbox(label="", lines=5, interactive=False)

    with gr.Row():
        with gr.Column():
            gr.Markdown("### Base Model (With RAG)")
            base_with_rag = gr.Textbox(label="", lines=5, interactive=False)
        with gr.Column():
            gr.Markdown("### Finetuned Model (With RAG)")
            finetuned_with_rag = gr.Textbox(label="", lines=5, interactive=False)

    with gr.Accordion("View Retrieved Documents (for RAG models)", open=False):
        docs_display = gr.Textbox(label="", lines=10, interactive=False)



    submit_btn.click(
        fn=get_answers,
        inputs=question,
        outputs=[base_no_rag, finetuned_no_rag, base_with_rag, finetuned_with_rag, docs_display]
    )

    toggle_btn.click(
        fn=toggle_evaluations,
        outputs=eval_status
    )

if __name__ == "__main__":
    demo.launch()



#--- ADD YOUR SOLUTION HERE (40 points)---
# Out:
# It looks like you are running Gradio on a hosted a Jupyter notebook. For the Gradio app to work, sharing must be enabled. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://790a1d147c59755a3b.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://790a1d147c59755a3b.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# # End
#
# This concludes assignment 4.
#
# Please submit this notebook with your answers and the generated output cells as a **Jupyter notebook file** via github.
#
#
# Every group member should do the following submission steps:
# 1. Create a private github repository **sutd_5055mlop** under your github user.
# 2. Add your instructors as collaborator: ddahlmeier and lucainiaoge
# 3. Save your submission as assignment_04_GROUP_NAME.ipynb where GROUP_NAME is the name of the group you have registered.
# 4. Push the submission files to your repo
# 5. Submit the link to the repo via eDimensions
#
#
#
# **Assignment due 21 April 2025 11:59pm**
